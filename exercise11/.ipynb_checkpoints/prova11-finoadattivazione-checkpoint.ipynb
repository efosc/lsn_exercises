# %% [markdown]
# ## Exericise 11
#
# In this exercise neural networks were applied to three different regression problems: a linear fit, a polynomial fit and a trigonometric 2D function.
#
# ### 11.1

# %% [markdown]
# The aim of exercise 11.1 is to fit a linear function $f(x)=2x+1$ using a single neuron NN.
#
# At first, the dataset for training and testing are created:
# 1. *training set*: measures used to train the model and optimize regression parameters. Points in this set are obtained by adding a gaussian noise to the linear target function,
# 2. *validation set* (10% of the training set): to test the model on a separate set not involved in the training process. Like the training set, this is evaluated from linear target function + gaussian noise with same $\sigma$ as in the training set,
# 3. *target set*: the actual target function without the gaussian noise. The model accuracy is evaluated on this set as well.
#
# The following graph reports the three dataset as an example, using 100 points for the training set, 10 points for the validation and target set (the latter is represented as a straight line, the other two as scatterplots).

# %%
### importing libraries
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects
#from tensorflow.keras.callbacks import EarlyStopping

# %%
# target parameters of f(x) = m*x + b
m = 2 # slope
b = 1 # intersect

# %%
# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 100)
x_valid = np.random.uniform(-1, 1, 10)
x_valid.sort()
y_target = m * x_valid + b # ideal (target) linear function

sigma = 0.5 # noise standard deviation
y_train = np.random.normal(m * x_train + b, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(m * x_valid + b, sigma)

# %%
# plot training and target dataset
plt.figure(figsize=(9,6))
plt.plot(x_valid, y_target, color = "red", label = "Target function")
plt.scatter(x_valid, y_valid, color='midnightblue', s=30, label="Validation set")
plt.scatter(x_train, y_train, color = "dodgerblue", s=15, label="Training set")
plt.xlabel("x",size=13)
plt.ylabel("y",size=13)
plt.title("Training and validation sets and target function")
plt.legend(loc="lower right", fontsize=13)
plt.grid(True); plt.show()

# %% [markdown]
# This first part of Lecture 11 focuses on three parameters: $N_{train}$ (the training set size), $\sigma$ (the gaussian noise standard deviation applied on the training and validation sets), $N_{epochs}$ (an epoch is a single run of the NN during the training phase). The *mean squared error* was used as loss function and metrics through the whole exercise.
#
# At first these parameters were set to: $N_{train} = 100$, $\sigma=0$, $N_{epochs}=30$. With this parameters setting, the loss function evaluated on the validation set resulted to be $\approx 0.3$. After that, the training set size $N_{train}$, $\sigma$ and the number of epochs $N_{epochs}$ were varied to see how the model is related to these parameters and to improve the fitting. The script was simply run several times varying manually $N_{train}$, $\sigma$ and $N_{epochs}$ to find the best combination of the three parameters.

# %% [markdown]
# **Varying $\sigma$**: $ \ \ \ $ ($N_{epochs}=40$, $N_{train}=100$)
#
# |sigma|predicted m|predicted b|loss on validation set|loss on target set|
# |---|---|---|---|---|
# |0.1|1.9332693|1.005875|0.010002939961850643|0.0011858774814754725|
# |0.3|2.0103765|1.0422844|0.07495731115341187|0.001961078029125929|
# |0.5|2.0715578|1.0032238|0.15864932537078857|0.001555219292640686|
# |0.7|1.975122|0.86201894|0.4242778718471527|0.020328989252448082|
# |0.9|2.0787158|0.9541927|0.8266009092330933|0.0027085761539638042|
# |1.3|1.9195483|0.6753314|0.862949013710022|0.11573337018489838|
#
# As expected, the loss function increases with $\sigma$ (the more the training data are spread, the more difficult it is to evaluate m and b). However, incresing the number of epochs it is possible to reduce the loss function on the target set (loss on validation set doesn't improve, this may be due to the fact that the validation set is spread as well).
#
# $ \\ $
#
# **Varying $N_{train}$**: $ \ \ \ $   ($N_{epochs}=40$, $\sigma=0.3$, $batch = 32$, validation set size always 10% of the training set size)
#
# |training set size|predicted m|predicted b|loss on validation set| loss on target set|
# |---|---|---|---|---|
# |70|2.0668828|1.028657|0.11259597539901733|0.0034668243024498224|
# |120|2.103306|1.0182844|0.09926555305719376|0.0027775231283158064|
# |200|2.0409226|0.9646509|0.10246913135051727|0.0020201418083161116|
# |500|2.0328834|0.97006744|0.09979042828083039|0.0013439443736569957|
# |1000|2.0022569|1.0069656|0.07386541679501533|4.926809080643579e-05|
#
# In general, predctions seem to improve increaing $N_{train}$, even if the loss function on the validation/target seem to depend more on $\sigma$ rather than $N_{train}$.
#
# $ \\ $
#
# **Varying $N_{epochs}$**: $ \ \ \ $   ($N_{train}= 500 $, $\sigma=0.3$, $batch = 32$, validation set size always 10% of the training set size)
#
# |# epochs|predicted m|predicted b|loss on validation set| loss on target set|
# |---|---|---|---|---|
# |50|2.031459|0.96656036|0.10073151409626008|0.0015440493111964315|
# |60|2.0192769|0.97956055|0.0599472776055336|0.000577559914381709|
# |75|2.0210502|1.0103799|0.0705984503030777|0.0002262158808298409|
# |100|1.9751853|0.9959381|0.08684590220451355|0.00020237264805473388|
# |200|1.9968362|0.9857125|0.09561826169490814|0.00020259216660633683|
#
# While the loss function on the target set decreases with $N_{epochs}$, the loss on the validation turns out to be higher for $N_{epochs} > \approx 60$. This could be a sign of possible overfitting.
#
# In conclusion, in the rest of the exercise 11.1 the parameters were set to: $\sigma = 0.3$, $N_{train} = 800$, $N_{epochs}=45$.

# %%
#compose the NN model
model = tf.keras.Sequential()
## one layer with one input
model.add(Dense(1, input_shape=(1,)))
# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
np.random.seed(0)
# generate training inputs
x_train = np.random.uniform(-1, 1, 800)
x_valid = np.random.uniform(-1, 1, 80)
x_valid.sort()
y_target = m * x_valid + b # ideal (target) linear function

sigma = 0.3 # noise standard deviation
y_train = np.random.normal(m * x_train + b, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(m * x_valid + b, sigma)
    
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=45,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/45
# 25/25 [==============================] - 0s 9ms/step - loss: 1.1202 - mse: 1.1202 - val_loss: 0.8109 - val_mse: 0.8109
# Epoch 2/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6057 - mse: 0.6057 - val_loss: 0.4681 - val_mse: 0.4681
# Epoch 3/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3762 - mse: 0.3762 - val_loss: 0.3069 - val_mse: 0.3069
# Epoch 4/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2632 - mse: 0.2632 - val_loss: 0.2225 - val_mse: 0.2225
# Epoch 5/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2008 - mse: 0.2008 - val_loss: 0.1742 - val_mse: 0.1742
# Epoch 6/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1631 - mse: 0.1631 - val_loss: 0.1441 - val_mse: 0.1441
# Epoch 7/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1387 - mse: 0.1387 - val_loss: 0.1244 - val_mse: 0.1244
# Epoch 8/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1223 - mse: 0.1223 - val_loss: 0.1111 - val_mse: 0.1111
# Epoch 9/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1110 - mse: 0.1110 - val_loss: 0.1019 - val_mse: 0.1019
# Epoch 10/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1030 - mse: 0.1030 - val_loss: 0.0955 - val_mse: 0.0955
# Epoch 11/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0975 - mse: 0.0975 - val_loss: 0.0911 - val_mse: 0.0911
# Epoch 12/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0936 - mse: 0.0936 - val_loss: 0.0880 - val_mse: 0.0880
# Epoch 13/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0908 - mse: 0.0908 - val_loss: 0.0858 - val_mse: 0.0858
# Epoch 14/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0888 - mse: 0.0888 - val_loss: 0.0842 - val_mse: 0.0842
# Epoch 15/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0874 - mse: 0.0874 - val_loss: 0.0831 - val_mse: 0.0831
# Epoch 16/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0865 - mse: 0.0865 - val_loss: 0.0824 - val_mse: 0.0824
# Epoch 17/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0857 - mse: 0.0857 - val_loss: 0.0818 - val_mse: 0.0818
# Epoch 18/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0852 - mse: 0.0852 - val_loss: 0.0814 - val_mse: 0.0814
# Epoch 19/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0849 - mse: 0.0849 - val_loss: 0.0811 - val_mse: 0.0811
# Epoch 20/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0846 - mse: 0.0846 - val_loss: 0.0809 - val_mse: 0.0809
# Epoch 21/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0844 - mse: 0.0844 - val_loss: 0.0808 - val_mse: 0.0808
# Epoch 22/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0843 - mse: 0.0843 - val_loss: 0.0807 - val_mse: 0.0807
# Epoch 23/45
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0842 - mse: 0.0842 - val_loss: 0.0806 - val_mse: 0.0806
# Epoch 24/45
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0842 - mse: 0.0842 - val_loss: 0.0806 - val_mse: 0.0806
# Epoch 25/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0841 - mse: 0.0841 - val_loss: 0.0806 - val_mse: 0.0806
# Epoch 26/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0841 - mse: 0.0841 - val_loss: 0.0806 - val_mse: 0.0806
# Epoch 27/45
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0841 - mse: 0.0841 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 28/45
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0841 - mse: 0.0841 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 29/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0841 - mse: 0.0841 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 30/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 31/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 32/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 33/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 34/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 35/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 36/45
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0841 - mse: 0.0841 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 37/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 38/45
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 39/45
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 40/45
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 41/45
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 42/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 43/45
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 44/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 45/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805

# %%
# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=0)

# print performance
print('mse on validation set:', score[0])

# evaluate model with the exact curve
score = model.evaluate(x_valid, y_target, batch_size=32, verbose=0)

# print performance
print('mse on target set:', score[0])
# Out:
# mse on validation set: 0.08053983747959137
# mse on target set: 0.00027955195400863886

# %% [markdown]
# The two graphs below show the result obtained with these parameters: the loss function trend during the training and predictions on a new set of data compared to the exact function.

# %%
##-> 45 epochs, sigma 0.3,  ntrain = 800
plt.figure(figsize=(9,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss',size=13)
plt.ylabel('Loss',size=13)
plt.xlabel('Epoch',size=13)
plt.legend(['Train', 'Test'], loc='best',fontsize=13)
plt.grid(True)
plt.show()

# %%
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)

plt.figure(figsize=(9,6))
plt.scatter(x_predicted, y_predicted, color = "r",s=20, label = "Predicted")
plt.plot(x_valid, y_target, label = "Target function")
plt.xlabel("x",size=13)
plt.ylabel("y",size=13)
plt.title("Predictions vs target function")
plt.legend(loc="lower right", fontsize=13)
plt.grid(True); plt.show()

# %% [markdown]
# ### 11.2

# %% [markdown]
# In this section the function to fit is: $f(x)=4-3x-2x^2+3x^3$ for $x \in [-1,1]$, focusing on the following parameters:
# - the number of layers $N_L$,
# - the number of neurons in each layer $N_n$,
# - the activation function,
# - the optimizer,
# - the loss function.
#
# The the metrics to evaluate the algorithm results on validation and target sets was always set to *mse* thoughout the exercise.

# %%
def func(x):
    return 4 - 3*x -2*(x**2) + 3*(x**3)

# %%
## training and validation sets 
np.random.seed(0)
# generate training inputs
x_train = np.random.uniform(-1, 1, 800)
x_valid = np.random.uniform(-1, 1, 80)
x_valid.sort()
y_target = func(x_valid) # ideal (target) linear function

sigma = 0.3 # noise standard deviation
y_train = np.random.normal(func(x_train), sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(func(x_valid), sigma)

# %%
plt.figure(figsize=(9,6))
plt.plot(x_valid, y_target, color = "red", label = "Target function")
plt.scatter(x_valid, y_valid, color='midnightblue', s=30, label="Validation set")
plt.scatter(x_train, y_train, color = "dodgerblue", s=10, label="Training set")
plt.xlabel("x",size=13)
plt.ylabel("y",size=13)
plt.title("Training set, validation set and target function")
plt.legend(loc="upper right", fontsize=13)
plt.grid(True); plt.show()

# %% [markdown]
# #### Number of layers & nodes per layer
#
# I varied the number of layers and nodes looking for the best combination of the two. In order to compare the result  I drew a heatmap reporting the mean square error on the target and validation set for each model. After that, I selected the models with the lowest *mse* and  plotted the predicted data along with the target function for comparison.

# %%
from itertools import product
models = [] 
Nl = [10,5,2] ## numero di layer
Nn = [3,10,15,25,50] ## numero di nodi
acc_val = []
acc_tar = []

for l,n in product(Nl, Nn): 
    model = tf.keras.Sequential()
    model.add(Dense(n, input_shape=(1,),activation="relu")) ## primo layer
    for i in range(l-1):  
        model.add(Dense(n, activation="relu"))
    model.add(Dense(1,activation="elu"))
    model.compile(optimizer='sgd', loss='mse', metrics=['mse'])
    model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=45,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid), verbose=0)
    models.append(model) ## nel vettore di modelli dopo il training
    print("model with " , l, " layers with ", n, " nodes each")
    # evaluate model
    score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=0)
    acc_val.append(score[1])
    print("mse on validation set = ", score[1])
    score = model.evaluate(x_valid, y_target, batch_size=32, verbose=0)
    acc_tar.append(score[1])
    print("mse on target set = ", score[1])
# Out:
# model with  10  layers with  3  nodes each
# mse on validation set =  1.20637047290802
# mse on target set =  1.17061185836792
# model with  10  layers with  10  nodes each
# mse on validation set =  0.09212411195039749
# mse on target set =  0.01682407222688198
# model with  10  layers with  15  nodes each
# mse on validation set =  0.08596016466617584
# mse on target set =  0.005220330320298672
# model with  10  layers with  25  nodes each
# mse on validation set =  0.09445537626743317
# mse on target set =  0.011823027394711971
# model with  10  layers with  50  nodes each
# mse on validation set =  0.0838482528924942
# mse on target set =  0.002636138815432787
# model with  5  layers with  3  nodes each
# mse on validation set =  0.09945035725831985
# mse on target set =  0.015820831060409546
# model with  5  layers with  10  nodes each
# mse on validation set =  0.09180082380771637
# mse on target set =  0.007933965884149075
# model with  5  layers with  15  nodes each
# mse on validation set =  0.08911432325839996
# mse on target set =  0.008293254300951958
# model with  5  layers with  25  nodes each
# mse on validation set =  0.08672920614480972
# mse on target set =  0.005289822816848755
# model with  5  layers with  50  nodes each
# mse on validation set =  0.09928421676158905
# mse on target set =  0.015719518065452576
# model with  2  layers with  3  nodes each
# mse on validation set =  0.2594729959964752
# mse on target set =  0.18480494618415833
# model with  2  layers with  10  nodes each
# mse on validation set =  0.11719546467065811
# mse on target set =  0.025679823011159897
# model with  2  layers with  15  nodes each
# mse on validation set =  0.11608318239450455
# mse on target set =  0.02700583077967167
# model with  2  layers with  25  nodes each
# mse on validation set =  0.1126476526260376
# mse on target set =  0.0238453708589077
# model with  2  layers with  50  nodes each
# mse on validation set =  0.10536129772663116
# mse on target set =  0.017421215772628784

# %%
acc_val2 = np.round(acc_val, decimals=3) 
acc_tar2 = np.round(acc_tar, decimals=3) 
acc_val2 = np.reshape(acc_val2,(3,5))
acc_tar2 = np.reshape(acc_tar2,(3,5))

# %%
acc_val
# Out:
# [1.20637047290802,
#  0.09212411195039749,
#  0.08596016466617584,
#  0.09445537626743317,
#  0.0838482528924942,
#  0.09945035725831985,
#  0.09180082380771637,
#  0.08911432325839996,
#  0.08672920614480972,
#  0.09928421676158905,
#  0.2594729959964752,
#  0.11719546467065811,
#  0.11608318239450455,
#  0.1126476526260376,
#  0.10536129772663116]

# %%
acc_val2
# Out:
# array([[1.206, 0.092, 0.086, 0.094, 0.084],
#        [0.099, 0.092, 0.089, 0.087, 0.099],
#        [0.259, 0.117, 0.116, 0.113, 0.105]])

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
#acc_val2 = np.reshape(acc_val2,(3,5))
#acc_tar2 = np.reshape(acc_tar2,(3,5))

fig, (ax1,ax2) = plt.subplots(1,2, figsize=(20,10))
divider = make_axes_locatable(ax1)
cax1 = divider.append_axes('right', size='5%', pad=0.05)
divider = make_axes_locatable(ax2)
cax2 = divider.append_axes('right', size='5%', pad=0.05)


im1 = ax1.imshow(acc_val2)
ax1.set_xticks(np.arange(len(Nn)))
ax1.set_yticks(np.arange(len(Nl)))
ax1.set_xticklabels(Nn,size=20)
ax1.set_yticklabels(Nl,size=20)
ax1.set_xlabel("Number of neurons per layer",size=20)
ax1.set_ylabel("Number of layers",size=20)
ax1.set_title("mse values on validation set", size=20)
plt.setp(ax1.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

for i in range(len(Nl)):
    for j in range(len(Nn)):
        text = ax1.text(j, i, acc_val2[i, j],
                       ha="center", va="center", color="w", size=20)

im2 = ax2.imshow(acc_tar2)
ax2.set_xticks(np.arange(len(Nn)))
ax2.set_yticks(np.arange(len(Nl)))
ax2.set_xticklabels(Nn,size=20)
ax2.set_yticklabels(Nl,size=20)
ax2.set_xlabel("Number of neurons per layer",size=20)
ax2.set_ylabel("Number of layers",size=20)
ax2.set_title("mse values on target set", size=20)
plt.setp(ax2.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

for i in range(len(Nl)):
    for j in range(len(Nn)):
        text = ax2.text(j, i, acc_tar2[i, j],
                       ha="center", va="center", color="w",size=20)
        
fig.colorbar(im1, cax=cax1, orientation='vertical')
fig.colorbar(im2, cax=cax2, orientation='vertical')

# %% [markdown]
# The heatmaps report the values of the mean squared error on the validation and target set obtrained with the *evaluate(...)* method. In general, it is possibe to notice that the models with best results have 5 or 10 layers with at least 10 neurons in each layer. The following models were applied on new data:
# - 10 layers, 10 neurons,
# - 10 layers, 15 neurons,
# - 10 layers, 25 neurons,
# - 10 layers, 50 neurons,
# - 5 layers, 10 neurons,
# - 5 layers, 25 neurons,
#
# and their predictions were compared to the target function.

# %%
x_predicted = np.random.uniform(-1.5, 1.5, 200)
y_predicted1 = models[1].predict(x_predicted)
y_predicted2 = models[2].predict(x_predicted)
y_predicted3 = models[3].predict(x_predicted)
y_predicted4 = models[4].predict(x_predicted)
y_predicted6 = models[6].predict(x_predicted)
y_predicted8 = models[8].predict(x_predicted)

plt.figure(figsize=(9,6))
plt.scatter(x_predicted, y_predicted1, s=10, label = "Predicted - 10 layers, 10 neurons")
plt.scatter(x_predicted, y_predicted2, s=10, label = "Predicted - 10 layers, 15 neurons")
plt.scatter(x_predicted, y_predicted3, s=10, label = "Predicted - 10 layers, 25 neurons")
plt.scatter(x_predicted, y_predicted4, s=10, label = "Predicted - 10 layers, 50 neurons")
plt.scatter(x_predicted, y_predicted6, s=10, label = "Predicted - 5 layers, 10 neurons")
plt.scatter(x_predicted, y_predicted8, s=10, label = "Predicted - 5 layers, 25 neurons")

plt.plot(x_valid, y_target, label = "Target function", color="k")
plt.xlabel("x",size=13)
plt.ylabel("y",size=13)
plt.title("Predictions vs target function", size=13)
plt.legend(loc="upper right", fontsize=10.5)
plt.grid(True); plt.show()

# %% [markdown]
# It is possible to notice that all these model give good predictions within the interval $[-1, 1]$ but are unable to correctly predict the target function beyond the training interval.
# #### Activation functions
#
# In this part various models with different activations functions were tested (the final activation function is always *elu*). All models have 10 layers and 25 neurons. At first just the *mse* results on validation and target sets were compared, and then the models with the lowest *mse* values (*elu*, *selu*, *relu*, *tanh*) are plotted along with the target function.

# %% [markdown]
# **open bounds activation functions:** ***elu, selu, relu, softplus***

# %%
## open bounds activation functions: elu, selu, relu, softplus
models2 = []
acc_val2 = []
acc_tar2 = []
act = ["elu", "relu", "selu", "softplus"]
##elu
n = 25
for a in act:
    model = tf.keras.Sequential()
    model.add(Dense(n, input_shape=(1,),activation=a)) ## primo layer
    for i in range(9):  
        model.add(Dense(n, activation=a))
    model.add(Dense(1,activation='elu'))
    model.compile(optimizer='sgd', loss='mse', metrics=['mse'])
    model.fit(x=x_train, y=y_train, 
              batch_size=32, epochs=45,
              shuffle=True, # a good idea is to shuffle input before at each epoch
              validation_data=(x_valid, y_valid))
    models2.append(model) ## nel vettore di modelli dopo il training
    print("model with ", a)
     # evaluate model
    score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=0)
    print("mse on validation set = ", score[1])
    acc_val2.append(score[1])
    score = model.evaluate(x_valid, y_target, batch_size=32, verbose=0)
    print("mse on target set = ", score[1])
    acc_tar2.append(score[1])
# Out:
# Epoch 1/45
# 25/25 [==============================] - 0s 10ms/step - loss: 2.0117 - mse: 2.0117 - val_loss: 0.4370 - val_mse: 0.4370
# Epoch 2/45
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4569 - mse: 0.4569 - val_loss: 0.3687 - val_mse: 0.3687
# Epoch 3/45
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3615 - mse: 0.3615 - val_loss: 0.3502 - val_mse: 0.3502
# Epoch 4/45
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2639 - mse: 0.2639 - val_loss: 0.2418 - val_mse: 0.2418
# Epoch 5/45
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1987 - mse: 0.1987 - val_loss: 0.2996 - val_mse: 0.2996
# Epoch 6/45
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1726 - mse: 0.1726 - val_loss: 0.2020 - val_mse: 0.2020
# Epoch 7/45
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1576 - mse: 0.1576 - val_loss: 0.1184 - val_mse: 0.1184
# Epoch 8/45
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1546 - mse: 0.1546 - val_loss: 0.1615 - val_mse: 0.1615
# Epoch 9/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1284 - mse: 0.1284 - val_loss: 0.1182 - val_mse: 0.1182
# Epoch 10/45
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1100 - mse: 0.1100 - val_loss: 0.1237 - val_mse: 0.1237
# Epoch 11/45
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1369 - mse: 0.1369 - val_loss: 0.1076 - val_mse: 0.1076
# Epoch 12/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1500 - mse: 0.1500 - val_loss: 0.1143 - val_mse: 0.1143
# Epoch 13/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1204 - mse: 0.1204 - val_loss: 0.1336 - val_mse: 0.1336
# Epoch 14/45
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1129 - mse: 0.1129 - val_loss: 0.1626 - val_mse: 0.1626
# Epoch 15/45
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1132 - mse: 0.1132 - val_loss: 0.1557 - val_mse: 0.1557
# Epoch 16/45
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1148 - mse: 0.1148 - val_loss: 0.1165 - val_mse: 0.1165
# Epoch 17/45
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1136 - mse: 0.1136 - val_loss: 0.1056 - val_mse: 0.1056
# Epoch 18/45
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1047 - mse: 0.1047 - val_loss: 0.1014 - val_mse: 0.1014
# Epoch 19/45
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1283 - mse: 0.1283 - val_loss: 0.1152 - val_mse: 0.1152
# Epoch 20/45
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1227 - mse: 0.1227 - val_loss: 0.1308 - val_mse: 0.1308
# Epoch 21/45
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1152 - mse: 0.1152 - val_loss: 0.1036 - val_mse: 0.1036
# Epoch 22/45
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1235 - mse: 0.1235 - val_loss: 0.1637 - val_mse: 0.1637
# Epoch 23/45
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1139 - mse: 0.1139 - val_loss: 0.3693 - val_mse: 0.3693
# Epoch 24/45
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1209 - mse: 0.1209 - val_loss: 0.1089 - val_mse: 0.1089
# Epoch 25/45
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1039 - mse: 0.1039 - val_loss: 0.0946 - val_mse: 0.0946
# Epoch 26/45
# 25/25 [==============================] - 0s 4ms/step - loss: 0.
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1435 - mse: 1.1435 - val_loss: 1.2072 - val_mse: 1.2072
# Epoch 39/45
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1475 - mse: 1.1475 - val_loss: 1.2531 - val_mse: 1.2531
# Epoch 40/45
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1461 - mse: 1.1461 - val_loss: 1.2053 - val_mse: 1.2053
# Epoch 41/45
# 25/25 [==============================] - 0s 2ms/step - loss: 1.1516 - mse: 1.1516 - val_loss: 1.2063 - val_mse: 1.2063
# Epoch 42/45
# 25/25 [==============================] - 0s 2ms/step - loss: 1.1436 - mse: 1.1436 - val_loss: 1.2142 - val_mse: 1.2142
# Epoch 43/45
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1503 - mse: 1.1503 - val_loss: 1.2104 - val_mse: 1.2104
# Epoch 44/45
# 25/25 [==============================] - 0s 2ms/step - loss: 1.1464 - mse: 1.1464 - val_loss: 1.2359 - val_mse: 1.2359
# Epoch 45/45
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1339 - mse: 1.1339 - val_loss: 1.2152 - val_mse: 1.2152
# model with  softplus
# mse on validation set =  1.2151658535003662
# mse on target set =  1.1762584447860718

# %%
act = ["elu", "relu", "selu", "softplus"]
i=0
for a in act:
    print(a, " -> mse on validation set: ", acc_val2[i])
    print(a, " -> mse on target set: ", acc_tar2[i])
    i = i+1
# Out:
# elu  -> mse on validation set:  0.0931275486946106
# elu  -> mse on target set:  0.0071505093947052956
# relu  -> mse on validation set:  0.12717217206954956
# relu  -> mse on target set:  0.04930907115340233
# selu  -> mse on validation set:  0.08995906263589859
# selu  -> mse on target set:  0.010841337032616138
# softplus  -> mse on validation set:  1.2151658535003662
# softplus  -> mse on target set:  1.1762584447860718

# %% [markdown]
# **activation functions wth plateau:** ***sigmoid, softsign, tanh, softmax***

# %%
## activation functions wth plateau: sigmoid, softsign, tanh, softmax
models3 = []
acc_val3 = []
acc_tar3 = []
act = ["sigmoid", "softsign", "tanh", "softmax"]
##elu
n = 25
for a in act:
    model = tf.keras.Sequential()
    model.add(Dense(n, input_shape=(1,),activation=a)) ## primo layer
    for i in range(9):  
        model.add(Dense(n, activation=a))
    model.add(Dense(1,activation='elu'))
    model.compile(optimizer='sgd', loss='mse', metrics=['mse'])
    model.fit(x=x_train, y=y_train, 
              batch_size=32, epochs=45,
              shuffle=True, # a good idea is to shuffle input before at each epoch
              validation_data=(x_valid, y_valid), verbose=0)
    models3.append(model) ## nel vettore di modelli dopo il training
    print("model with ", a)
     # evaluate model
    score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=0)
    print("mse on validation set = ", score[1])
    acc_val3.append(score[1])
    score = model.evaluate(x_valid, y_target, batch_size=32, verbose=0)
    print("mse on target set = ", score[1])
    acc_tar3.append(score[1])
# Out:
# model with  sigmoid
# mse on validation set =  1.2066370248794556
# mse on target set =  1.1700680255889893
# model with  softsign
# mse on validation set =  0.12259350717067719
# mse on target set =  0.04274788871407509
# model with  tanh
# mse on validation set =  0.08322448283433914
# mse on target set =  0.0036819488741457462
# model with  softmax
# mse on validation set =  1.2063595056533813
# mse on target set =  1.1705843210220337

# %%
# plot
x_predicted = np.random.uniform(-1.5, 1.5, 200)
act = ["elu", "relu", "selu", "tanh", "softsign"]
plt.figure(figsize=(9,6))

for i in range(3):
    y_predicted = models2[i].predict(x_predicted)
    plt.scatter(x_predicted, y_predicted, s=10, label = "Predicted - " + act[i])
y_predicted = models3[2].predict(x_predicted)
plt.scatter(x_predicted, y_predicted, s=10, label = "Predicted - tanh")
y_predicted = models3[1].predict(x_predicted)
plt.scatter(x_predicted, y_predicted, s=10, label = "Predicted - softsign")
plt.plot(x_valid, y_target, label = "Target function", color="k")
plt.xlabel("x",size=13)
plt.ylabel("y",size=13)
plt.title("Predictions vs target function (10 layers + 25 neurons)", size=13)
plt.legend(loc="upper right", fontsize=11)
plt.grid(True); plt.show()

# %% [markdown]
# Is possible to notice that *elu*, *relu* and *tanh* give the best results (in a model with 10 layers of 25 neurons each).
#
# #### Optimizers
#
# In this part three diffent optimizers (*Adagrad*, *Adadelta*, *Sgd*) were compared. The graphs report predictions obtained with the three models, compared to the target function.

# %%
n = 25

model1 = tf.keras.Sequential()
model1.add(Dense(n, input_shape=(1,),activation="elu")) ## primo layer
for i in range(9):  
        model1.add(Dense(n, activation="elu"))
model1.add(Dense(1,activation='elu'))
model1.compile(optimizer=keras.optimizers.Adagrad(lr=0.01, epsilon=None, decay=0.0), loss='mse', metrics=['mse'])
model1.fit(x=x_train, y=y_train, 
              batch_size=32, epochs=45,
              shuffle=True, # a good idea is to shuffle input before at each epoch
              validation_data=(x_valid, y_valid))
     # evaluate model
score = model1.evaluate(x_valid, y_valid, batch_size=32, verbose=0)
print("mse on validation set = ", score[1])
score = model1.evaluate(x_valid, y_target, batch_size=32, verbose=0)
print("mse on target set = ", score[1])
# Out:
# Epoch 1/45
# 16/16 [==============================] - 0s 15ms/step - loss: 2.6550 - mse: 2.6550 - val_loss: 0.6228 - val_mse: 0.6228
# Epoch 2/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4695 - mse: 0.4695 - val_loss: 0.6491 - val_mse: 0.6491
# Epoch 3/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4305 - mse: 0.4305 - val_loss: 0.4996 - val_mse: 0.4996
# Epoch 4/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3782 - mse: 0.3782 - val_loss: 0.4056 - val_mse: 0.4056
# Epoch 5/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3386 - mse: 0.3386 - val_loss: 0.3468 - val_mse: 0.3468
# Epoch 6/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3064 - mse: 0.3064 - val_loss: 0.3156 - val_mse: 0.3156
# Epoch 7/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2598 - mse: 0.2598 - val_loss: 0.4233 - val_mse: 0.4233
# Epoch 8/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1884 - mse: 0.1884 - val_loss: 0.2307 - val_mse: 0.2307
# Epoch 9/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1792 - mse: 0.1792 - val_loss: 0.1486 - val_mse: 0.1486
# Epoch 10/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1359 - mse: 0.1359 - val_loss: 0.1636 - val_mse: 0.1636
# Epoch 11/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1422 - mse: 0.1422 - val_loss: 0.1035 - val_mse: 0.1035
# Epoch 12/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1393 - mse: 0.1393 - val_loss: 0.0940 - val_mse: 0.0940
# Epoch 13/45
# 16/16 [==============================] - 0s 7ms/step - loss: 0.1255 - mse: 0.1255 - val_loss: 0.1013 - val_mse: 0.1013
# Epoch 14/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.
45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1004 - mse: 0.1004 - val_loss: 0.0822 - val_mse: 0.0822
# mse on validation set =  0.08221907913684845
# mse on target set =  0.01638016290962696

# %%
n = 25

model2 = tf.keras.Sequential()
model2.add(Dense(n, input_shape=(1,),activation="elu")) ## primo layer
for i in range(9):  
        model2.add(Dense(n, activation="elu"))
model2.add(Dense(1,activation='elu'))
model2.compile(optimizer=keras.optimizers.Adadelta(lr=1.0, rho=0.95, epsilon=None, decay=0.0), loss='mse', metrics=['mse'])
model2.fit(x=x_train, y=y_train, 
              batch_size=32, epochs=45,
              shuffle=True, # a good idea is to shuffle input before at each epoch
              validation_data=(x_valid, y_valid))
     # evaluate model
score = model2.evaluate(x_valid, y_valid, batch_size=32, verbose=0)
print("mse on validation set = ", score[1])
score = model2.evaluate(x_valid, y_target, batch_size=32, verbose=0)
print("mse on target set = ", score[1])
# Out:
# Epoch 1/45
# 16/16 [==============================] - 0s 17ms/step - loss: 4.6079 - mse: 4.6079 - val_loss: 0.9657 - val_mse: 0.9657
# Epoch 2/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5979 - mse: 0.5979 - val_loss: 0.7031 - val_mse: 0.7031
# Epoch 3/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4579 - mse: 0.4579 - val_loss: 0.5733 - val_mse: 0.5733
# Epoch 4/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4267 - mse: 0.4267 - val_loss: 0.6852 - val_mse: 0.6852
# Epoch 5/45
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4780 - mse: 0.4780 - val_loss: 0.5199 - val_mse: 0.5199
# Epoch 6/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4260 - mse: 0.4260 - val_loss: 0.3039 - val_mse: 0.3039
# Epoch 7/45
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2670 - mse: 0.2670 - val_loss: 0.5139 - val_mse: 0.5139
# Epoch 8/45
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2698 - mse: 0.2698 - val_loss: 0.4275 - val_mse: 0.4275
# Epoch 9/45
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2426 - mse: 0.2426 - val_loss: 0.3911 - val_mse: 0.3911
# Epoch 10/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2645 - mse: 0.2645 - val_loss: 0.1746 - val_mse: 0.1746
# Epoch 11/45
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1999 - mse: 0.1999 - val_loss: 0.4234 - val_mse: 0.4234
# Epoch 12/45
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1954 - mse: 0.1954 - val_loss: 0.2904 - val_mse: 0.2904
# Epoch 13/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1998 - mse: 0.1998 - val_loss: 0.2867 - val_mse: 0.2867
# Epoch 14/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1545 - mse: 0.1545 - val_loss: 0.1285 - val_mse: 0.1285
# Epoch 15/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2002 - mse: 0.2002 - val_loss: 0.1050 - val_mse: 0.1050
# Epoch 16/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2143 - mse: 0.2143 - val_loss: 0.5972 - val_mse: 0.5972
# Epoch 17/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1515 - mse: 0.1515 - val_loss: 0.4197 - val_mse: 0.4197
# Epoch 18/45
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2623 - mse: 0.2623 - val_loss: 0.0888 - val_mse: 0.0888
# Epoch 19/45
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1201 - mse: 0.1201 - val_loss: 0.0971 - val_mse: 0.0971
# Epoch 20/45
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1457 - mse: 0.1457 - val_loss: 0.1177 - val_mse: 0.1177
# Epoch 21/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1126 - mse: 0.1126 - val_loss: 0.1334 - val_mse: 0.1334
# Epoch 22/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1017 - mse: 0.1017 - val_loss: 0.1615 - val_mse: 0.1615
# Epoch 23/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1864 - mse: 0.1864 - val_loss: 0.2939 - val_mse: 0.2939
# Epoch 24/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1254 - mse: 0.1254 - val_loss: 0.0940 - val_mse: 0.0940
# Epoch 25/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1574 - mse: 0.1574 - val_loss: 0.0903 - val_mse: 0.0903
# Epoch 26/45
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1235 - mse: 0.1235 - val_loss: 0.0818 - val_mse: 0.0818
# Epoch 27/45
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1157 - mse: 0.1157 - val_loss: 0.1028 - val_mse: 0.1028
# Epoch 28/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1233 - mse: 0.1233 - val_loss: 0.2151 - val_mse: 0.2151
# Epoch 29/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1805 - mse: 0.1805 - val_loss: 0.1765 - val_mse: 0.1765
# Epoch 30/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1476 - mse: 0.1476 - val_loss: 0.3942 - val_mse: 0.3942
# Epoch 31/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1213 - mse: 0.1213 - val_loss: 0.1268 - val_mse: 0.1268
# Epoch 32/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1074 - mse: 0.1074 - val_loss: 0.1467 - val_mse: 0.1467
# Epoch 33/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1184 - mse: 0.1184 - val_loss: 0.1258 - val_mse: 0.1258
# Epoch 34/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1408 - mse: 0.1408 - val_loss: 0.1213 - val_mse: 0.1213
# Epoch 35/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1134 - mse: 0.1134 - val_loss: 0.0934 - val_mse: 0.0934
# Epoch 36/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1603 - mse: 0.1603 - val_loss: 0.1114 - val_mse: 0.1114
# Epoch 37/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1436 - mse: 0.1436 - val_loss: 0.1614 - val_mse: 0.1614
# Epoch 38/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1222 - mse: 0.1222 - val_loss: 0.1815 - val_mse: 0.1815
# Epoch 39/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1483 - mse: 0.1483 - val_loss: 0.2117 - val_mse: 0.2117
# Epoch 40/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1340 - mse: 0.1340 - val_loss: 0.1433 - val_mse: 0.1433
# Epoch 41/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1398 - mse: 0.1398 - val_loss: 0.0944 - val_mse: 0.0944
# Epoch 42/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1315 - mse: 0.1315 - val_loss: 0.0898 - val_mse: 0.0898
# Epoch 43/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1173 - mse: 0.1173 - val_loss: 0.0857 - val_mse: 0.0857
# Epoch 44/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1382 - mse: 0.1382 - val_loss: 0.2884 - val_mse: 0.2884
# Epoch 45/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1505 - mse: 0.1505 - val_loss: 0.1716 - val_mse: 0.1716
# mse on validation set =  0.17163926362991333
# mse on target set =  0.04993874952197075

# %%
# plot
x_predicted = np.random.uniform(-1.5, 1.5, 200)
y_predicted1 = model1.predict(x_predicted)
y_predicted2 = model2.predict(x_predicted)
y_predicted3 = models2[0].predict(x_predicted)


plt.figure(figsize=(9,6))

plt.scatter(x_predicted, y_predicted1, s=10, label = "Predicted - 10 layers, 25 nodes - Adagrad")
plt.scatter(x_predicted, y_predicted2, s=10, label = "Predicted - 10 layers, 25 nodes - Adadelta")
plt.scatter(x_predicted, y_predicted3, s=10, label = "Predicted - 10 layers, 25 nodes - Sgd")
plt.plot(x_valid, y_target, label = "Target function")
plt.xlabel("x",size=13)
plt.ylabel("y",size=13)
plt.title("Predictions vs target function", size=13)
plt.legend(loc="lower right", fontsize=11)
plt.grid(True); plt.show()

# %% [markdown]
# #### Loss functions
#
# In this section different combinations of activation function + loss function were compared.
# - the following loss functions were considered: *mse, mae, mean_squared_logarithmic_error , logcosh*;
# - for the last layer two possible activation function were selected: *elu*, *selu*;
# - in all the other layers the 4 best activation functions from the previous section were compared: *tanh, relu, elu, selu*.
#
# In order to make comparisons, I drew a heatmap reporting the mean square error on the target and validation set for each model (as I did in the *layers&neurons* section). After that, I selected the models with the lowest *mse* and plotted the predicted data along with the target function for comparison.

# %%
from itertools import product
n = 25
model_loss = []
accval_loss = []
acctar_loss = []

loss = ["mse", "mae", "msle", "logcosh"]
act = ["tanh", "relu", "elu", "selu"]
act_last = ["elu", "selu"]

for l, a, al in product(loss, act, act_last):
    modelnew = tf.keras.Sequential()
    modelnew.add(Dense(n, input_shape=(1,),activation=a)) ## primo layer
    for i in range(9):  
        modelnew.add(Dense(n, activation=a))
    modelnew.add(Dense(1,activation=al))
    modelnew.compile(optimizer="Sgd", loss=l, metrics=['mse'])
    modelnew.fit(x=x_train, y=y_train, 
                  batch_size=32, epochs=45,
                  shuffle=True, # a good idea is to shuffle input before at each epoch
                  validation_data=(x_valid, y_valid), verbose=0)
    model_loss.append(modelnew)
    print("Model with ", l, "as loss, " , a, " as activation function, ", al, " as activation function in the last layer")
 # evaluate model
    score = modelnew.evaluate(x_valid, y_valid, batch_size=32, verbose=0)
    accval_loss.append(score[1])
    print("mse on validation set = ", score[1])
    score = modelnew.evaluate(x_valid, y_target, batch_size=32, verbose=0)
    print("mse on target set = ", score[1])
    acctar_loss.append(score[1])
# Out:
# Model with  mse as loss,  tanh  as activation function,  elu  as activation function in the last layer
# mse on validation set =  0.09904024004936218
# mse on target set =  0.03999171406030655
# Model with  mse as loss,  tanh  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.09909673035144806
# mse on target set =  0.02170131728053093
# Model with  mse as loss,  relu  as activation function,  elu  as activation function in the last layer
# mse on validation set =  0.1167040467262268
# mse on target set =  0.01671506091952324
# Model with  mse as loss,  relu  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.17087873816490173
# mse on target set =  0.04894779622554779
# Model with  mse as loss,  elu  as activation function,  elu  as activation function in the last layer
# mse on validation set =  0.0902978926897049
# mse on target set =  0.0325503796339035
# Model with  mse as loss,  elu  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.10382325202226639
# mse on target set =  0.014208486303687096
# Model with  mse as loss,  selu  as activation function,  elu  as activation function in the last layer
# mse on validation set =  0.09800941497087479
# mse on target set =  0.014938022941350937
# Model with  mse as loss,  selu  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.1304502934217453
# mse on target set =  0.02193242497742176
# Model with  mae as loss,  tanh  as activation function,  elu  as activation function in the last layer
# mse on validation set =  0.15441596508026123
# mse on target set =  0.035981684923172
# Model with  mae as loss,  tanh  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.09482736885547638
# mse on target set =  0.03122430294752121
# Model with  mae as loss,  relu  as activation function,  elu  as activation function in the last layer
# mse on validation set =  0.13238021731376648
# mse on target set =  0.0271343681961298
# Model with  mae as loss,  relu  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.1597544103860855
# mse on target set =  0.04817642271518707
# Model with  mae as loss,  elu  as activation function,  elu  as activation function in the last layer
# mse on validation set =  0.09248773753643036
# mse on target set =  0.020730573683977127
# Model with  mae as loss,  elu  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.08544298261404037
# mse on target set =  0.02366766706109047
# Model with  mae as loss,  selu  as activation function,  elu  as activation function in the last layer
# mse on validation set =  0.20917080342769623
# mse on target set =  0.21437712013721466
# Model with  mae as loss,  selu  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.199371337890625
# mse on target set =  0.11896400153636932
# Model with  msle as loss,  tanh  as activation function,  elu  as activation function in the last layer
# mse on validation set =  0.4989306926727295
# mse on target set =  0.4522104561328888
# Model with  msle as loss,  tanh  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.44840213656425476
# mse on target set =  0.39985495805740356
# Model with  msle as loss,  relu  as activation function,  elu  as activation function in the last layer
# mse on validation set =  12.798819541931152
# mse on target set =  12.077877044677734
# Model with  msle as loss,  relu  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.9104644656181335
# mse on target set =  0.860251247882843
# Model with  msle as loss,  elu  as activation function,  elu  as activation function in the last layer
# mse on validation set =  0.40737462043762207
# mse on target set =  0.3603898882865906
# Model with  msle as loss,  elu  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.6623625159263611
# mse on target set =  0.6257726550102234
# Model with  msle as loss,  selu  as activation function,  elu  as activation function in the last layer
# mse on validation set =  0.0950716957449913
# mse on target set =  0.007415435276925564
# Model with  msle as loss,  selu  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.1358814835548401
# mse on target set =  0.05096498876810074
# Model with  logcosh as loss,  tanh  as activation function,  elu  as activation function in the last layer
# mse on validation set =  0.09687373042106628
# mse on target set =  0.02139303646981716
# Model with  logcosh as loss,  tanh  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.11530643701553345
# mse on target set =  0.05206174775958061
# Model with  logcosh as loss,  relu  as activation function,  elu  as activation function in the last layer
# mse on validation set =  0.5492867827415466
# mse on target set =  0.5342646241188049
# Model with  logcosh as loss,  relu  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.10309528559446335
# mse on target set =  0.02698657102882862
# Model with  logcosh as loss,  elu  as activation function,  elu  as activation function in the last layer
# mse on validation set =  0.11976304650306702
# mse on target set =  0.025050515308976173
# Model with  logcosh as loss,  elu  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.10256662964820862
# mse on target set =  0.039251234382390976
# Model with  logcosh as loss,  selu  as activation function,  elu  as activation function in the last layer
# mse on validation set =  0.08092927932739258
# mse on target set =  0.020134709775447845
# Model with  logcosh as loss,  selu  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.1334942728281021
# mse on target set =  0.05576746165752411

# %%
acctar_loss_elu = []
acctar_loss_selu = []
for i in range(len(acctar_loss)):
    if (i%2 == 0):
        acctar_loss_elu.append(acctar_loss[i])
    else:
        acctar_loss_selu.append(acctar_loss[i])

acctar_loss_elu = np.round(acctar_loss_elu, decimals=3)
acctar_loss_selu = np.round(acctar_loss_selu, decimals=3)

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
## righe = loss, cols = attivazione
acctar_loss_elu = np.reshape(acctar_loss_elu,(4,4))
acctar_loss_selu = np.reshape(acctar_loss_selu,(4,4))

fig, (ax1,ax2) = plt.subplots(1,2, figsize=(20,10))
divider = make_axes_locatable(ax1)
cax1 = divider.append_axes('right', size='5%', pad=0.05)
divider = make_axes_locatable(ax2)
cax2 = divider.append_axes('right', size='5%', pad=0.05)

im1 = ax1.imshow(acctar_loss_elu)
ax1.set_xticks(np.arange(len(loss)))
ax1.set_yticks(np.arange(len(act)))
ax1.set_xticklabels(loss,size=18)
ax1.set_yticklabels(act,size=18)
ax1.set_xlabel("Loss function",size=18)
ax1.set_ylabel("Activation function",size=18)
ax1.set_title("mse values on target set - elu in the last layer", size=18)
plt.setp(ax1.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

for i in range(len(loss)):
    for j in range(len(act)):
        text = ax1.text(j, i, acctar_loss_elu[i, j],
                       ha="center", va="center", color="w", size=20)

im2 = ax2.imshow(acctar_loss_selu)
ax2.set_xticks(np.arange(len(loss)))
ax2.set_yticks(np.arange(len(act)))
ax2.set_xticklabels(loss,size=18)
ax2.set_yticklabels(act,size=18)
ax2.set_xlabel("Loss function",size=18)
ax2.set_ylabel("Activation function",size=18)
ax2.set_title("mse values on target set - selu in the last layer", size=18)
plt.setp(ax1.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

for i in range(len(loss)):
    for j in range(len(act)):
        text = ax2.text(j, i, acctar_loss_selu[i, j],
                       ha="center", va="center", color="w", size=20)
        
fig.colorbar(im1, cax=cax1, orientation='vertical')
fig.colorbar(im2, cax=cax2, orientation='vertical')

# %% [markdown]
# In general, it is possible to notice that *tanh* obtained the best results.
# Models with the lowest mse were plotted:
# - mse, tanh, selu in the last layer
# - logcosh, tanh, selu in the last layer
# - logcosh, elu, selu in the last layer
# - logcosh, elu, elu in the last layer

# %%
model_elu = []
model_selu = []
for i in range(len(model_loss)):
    if (i%2 == 0):
        model_elu.append(model_loss[i])
    else:
        model_selu.append(model_loss[i])

# plot
x_predicted = np.random.uniform(-1.5, 1.5, 200)
y_predicted1 = model_selu[0].predict(x_predicted) #mse, tanh, selu in the last layer
y_predicted2 = model_selu[3].predict(x_predicted) #logcosh, tanh, selu in the last layer
y_predicted3 = model_selu[11].predict(x_predicted) #logcosh, elu, selu in the last layer
y_predicted4 = model_elu[11].predict(x_predicted) #logcosh, elu, elu in the last layer

plt.figure(figsize=(9,6))

plt.scatter(x_predicted, y_predicted1, s=10, label = "mse, tanh, selu in the last layer")
plt.scatter(x_predicted, y_predicted2, s=10, label = "logcosh, tanh, selu in the last layer")
plt.scatter(x_predicted, y_predicted3, s=10, label = "logcosh, elu, selu in the last layer")
plt.scatter(x_predicted, y_predicted4, s=10, label = "logcosh, elu, elu in the last layer")
plt.plot(x_valid, y_target, label = "Target function", color="k")
plt.xlabel("x",size=13)
plt.ylabel("y",size=13)
plt.title("Predictions vs target function", size=13)
plt.legend(loc="upper right", fontsize=10)
plt.grid(True); plt.show()

# %% [markdown]
# In general, increasing the number of layers and neurons (and thus the complexity of the model) seems to improve the NN results (lower *mse*, prediction fitting the target function). However, it could be argued that this is only true when comparing simple NN (as I did in this notebook). Indeed, the NN performances significantly improve when changing the number of neurons from 3 to 10, while it can be noticed that changing it from 25 to 50 produces just a little improvement. Finally, none of the tested model was able to correcly predict the target function outside the training dataset.

# %% [markdown]
# ### 11.3
#
# In this part the NN was applied to a 2D function: $f(x,y) = \sin(x^2+y^2)$ in the range $x \in [-3/2,3/2]$ and $y \in [-3/2,3/2]$.
#
# At first, I tried to apply the model with the best score in 11.2, just using *linear* as activation function in the last layer instead of *selu*:
# - 10 layers of 25 nodes each,
# - *mse* as loss function,
# - *tanh* as activation function in all the layers except for the last + *linear* in the last layer.
#
# Moreover, I increased the size of training and validation sets (keeping $N_{valid} = 0.1 \times N_{train}$) and slightly reduced the noise standard deviation.

# %%
### importing libraries
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects
#from tensorflow.keras.callbacks import EarlyStopping

# %%
def func2d (x,y):
    a = x**2 + y**2
    return np.sin(a)

# %%
## training and validation sets
np.random.seed(0)
ntrain = 20000
nvalid = 2000

x_train = np.random.uniform(-1.5, 1.5, ntrain)
x_valid = np.random.uniform(-1.5, 1.5, nvalid)
x_valid.sort()
y_train = np.random.uniform(-1.5, 1.5, ntrain)
y_valid = np.random.uniform(-1.5, 1.5, nvalid)
y_valid.sort()

z_target = func2d(x_valid, y_valid) # ideal (target) function

sigma = 0.25 # noise or standard deviation
z_train = np.random.normal(func2d(x_train, y_train), sigma) # actual measures from which we want to guess regression parameters
z_valid = np.random.normal(func2d(x_valid, y_valid), sigma)

## algo input
data_train = np.zeros((ntrain,2))
data_valid = np.zeros((nvalid, 2))
for i in range(ntrain):
    data_train[i,0] = x_train[i]
    data_train[i,1] = y_train[i]
for j in range(nvalid):
    data_valid[j,0] = x_valid[j]
    data_valid[j,1] = y_valid[j]

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter


fig = plt.figure(figsize=(9,9))
ax = fig.gca(projection='3d')

# Make data.
X = x_valid
Y = y_valid
X, Y = np.meshgrid(X, Y)
R = (X**2 + Y**2)
Z = np.sin(R)

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap="Blues",
                       linewidth=0, antialiased=False)
## Add points
ax.scatter(x_train, y_train, z_train, color = "aqua", s=10, label="Training set")
ax.scatter(x_valid, y_valid, z_valid, color='green', s=30, label="Validation set")

ax.set_xlabel("x",size=13)
ax.set_ylabel("y",size=13)
ax.set_title("Training set, validation set and target function", size=13)
ax.legend(loc="upper right", fontsize=13)
ax.view_init(15, 20)
# Add a color bar which maps values to colors
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
###MODEL 1: 10 layers of 25 nodes each, 
###*mse* as loss function, tanh + selu

model1 = Sequential()
model1.add(Dense(25, input_shape=(2,), activation='tanh')) 
for i in range(8):
    model1.add(Dense(25, activation='tanh'))
model1.add(Dense(1, activation='linear'))
model1.compile(optimizer='sgd', loss='mse', metrics=['mse'])

model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 25)                75
# _________________________________________________________________
# dense_1 (Dense)              (None, 25)                650
# _________________________________________________________________
# dense_2 (Dense)              (None, 25)                650
# _________________________________________________________________
# dense_3 (Dense)              (None, 25)                650
# _________________________________________________________________
# dense_4 (Dense)              (None, 25)                650
# _________________________________________________________________
# dense_5 (Dense)              (None, 25)                650
# _________________________________________________________________
# dense_6 (Dense)              (None, 25)                650
# _________________________________________________________________
# dense_7 (Dense)              (None, 25)                650
# _________________________________________________________________
# dense_8 (Dense)              (None, 25)                650
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 26
# =================================================================
# Total params: 5,301
# Trainable params: 5,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
history1 = model1.fit(x=data_train, y=z_train, 
          batch_size=128, epochs=100,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(data_valid, z_valid))
# Out:
# Epoch 1/100
# 157/157 [==============================] - 1s 3ms/step - loss: 0.2266 - mse: 0.2266 - val_loss: 0.4264 - val_mse: 0.4264
# Epoch 2/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2136 - mse: 0.2136 - val_loss: 0.4448 - val_mse: 0.4448
# Epoch 3/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2124 - mse: 0.2124 - val_loss: 0.4534 - val_mse: 0.4534
# Epoch 4/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2114 - mse: 0.2114 - val_loss: 0.4231 - val_mse: 0.4231
# Epoch 5/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2106 - mse: 0.2106 - val_loss: 0.4459 - val_mse: 0.4459
# Epoch 6/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2098 - mse: 0.2098 - val_loss: 0.4196 - val_mse: 0.4196
# Epoch 7/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2088 - mse: 0.2088 - val_loss: 0.4123 - val_mse: 0.4123
# Epoch 8/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2071 - mse: 0.2071 - val_loss: 0.4450 - val_mse: 0.4450
# Epoch 9/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2050 - mse: 0.2050 - val_loss: 0.4205 - val_mse: 0.4205
# Epoch 10/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2016 - mse: 0.2016 - val_loss: 0.4290 - val_mse: 0.4290
# Epoch 11/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1968 - mse: 0.1968 - val_loss: 0.3832 - val_mse: 0.3832
# Epoch 12/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1915 - mse: 0.1915 - val_loss: 0.3861 - val_mse: 0.3861
# Epoch 13/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1844 - mse: 0.1844 - val_loss: 0.3597 - val_mse: 0.3597
# Epoch 14/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1746 - mse: 0.1746 - val_loss: 0.3712 - val_mse: 0.3712
# Epoch 15/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1615 - mse: 0.1615 - val_loss: 0.3351 - val_mse: 0.3351
# Epoch 16/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1480 - mse: 0.1480 - val_loss: 0.3242 - val_mse: 0.3242
# Epoch 17/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1403 - mse: 0.1403 - val_loss: 0.2996 - val_mse: 0.2996
# Epoch 18/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1356 - mse: 0.1356 - val_loss: 0.2901 - val_mse: 0.2901
# Epoch 19/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1335 - mse: 0.1335 - val_loss: 0.2735 - val_mse: 0.2735
# Epoch 20/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1316 - mse: 0.1316 - val_loss: 0.3096 - val_mse: 0.3096
# Epoch 21/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1306 - mse: 0.1306 - val_loss: 0.2784 - val_mse: 0.2784
# Epoch 22/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1273 - mse: 0.1273 - val_loss: 0.2511 - val_mse: 0.2511
# Epoch 23/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1261 - mse: 0.1261 - val_loss: 0.2416 - val_mse: 0.2416
# Epoch 24/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1238 - mse: 0.1238 - val_loss: 0.2716 - val_mse: 0.2716
# Epoch 25/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1220 - mse: 0.1220 - val_loss: 0.2444 - val_mse: 0.2444
# Epoch 26/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1203 - mse: 0.1203 - val_loss: 0.2515 - val_mse: 0.2515
# Epoch 27/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1209 - mse: 0.1209 - val_loss: 0.2258 - val_mse: 0.2258
# Epoch 28/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.
100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0663 - mse: 0.0663 - val_loss: 0.0693 - val_mse: 0.0693
# Epoch 94/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0658 - mse: 0.0658 - val_loss: 0.0672 - val_mse: 0.0672
# Epoch 95/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0662 - mse: 0.0662 - val_loss: 0.0714 - val_mse: 0.0714
# Epoch 96/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0656 - mse: 0.0656 - val_loss: 0.0671 - val_mse: 0.0671
# Epoch 97/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0657 - mse: 0.0657 - val_loss: 0.0660 - val_mse: 0.0660
# Epoch 98/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0656 - mse: 0.0656 - val_loss: 0.0679 - val_mse: 0.0679
# Epoch 99/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0655 - mse: 0.0655 - val_loss: 0.0667 - val_mse: 0.0667
# Epoch 100/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0655 - mse: 0.0655 - val_loss: 0.0852 - val_mse: 0.0852

# %%
# evaluate model
score = model1.evaluate(data_valid, z_valid, batch_size=128, verbose=0)
print("mse on validation set = ", score[1])
score = model1.evaluate(data_valid, z_target, batch_size=128, verbose=0)
print("mse on target set = ", score[1])
# Out:
# mse on validation set =  0.08516904711723328
# mse on target set =  0.023002469912171364

# %%
## plot loss function during training
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('Model loss function during training')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.grid(True)
plt.show()

# %%
x_predicted1 = np.random.uniform(-1.5, 1.5, nvalid)
y_predicted1 = np.random.uniform(-1.5, 1.5, nvalid)
data_predicted1 = np.zeros((nvalid,2))
for k in range(nvalid):
    data_predicted1[k,0] = x_predicted1[k]
    data_predicted1[k,1] = y_predicted1[k]

z_predicted1 = model1.predict(data_predicted1)

# %% [markdown]
# The NN correclty predicts the data. However, the loss function shows a decreasing trend but keeps oscillating during training. Therefore I tried reducing the number of inner layers to make the model simpler.

# %%
## 4 layer, 25 nodes, mse, tanh+linear
model2 = Sequential()
model2.add(Dense(15, input_shape=(2,), activation='tanh'))
model2.add(Dense(25, activation='tanh'))
model2.add(Dense(25, activation='tanh'))
model2.add(Dense(1, activation='linear'))
model2.compile(optimizer='sgd', loss='mse', metrics=['mse'])

model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 15)                45
# _________________________________________________________________
# dense_11 (Dense)             (None, 25)                400
# _________________________________________________________________
# dense_12 (Dense)             (None, 25)                650
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 26
# =================================================================
# Total params: 1,121
# Trainable params: 1,121
# Non-trainable params: 0
# _________________________________________________________________

# %%
history2 = model2.fit(x=data_train, y=z_train, 
          batch_size=128, epochs=150,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(data_valid, z_valid))
# Out:
# Epoch 1/150
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2370 - mse: 0.2370 - val_loss: 0.4419 - val_mse: 0.4419
# Epoch 2/150
# 157/157 [==============================] - 0s 1ms/step - loss: 0.2160 - mse: 0.2160 - val_loss: 0.4336 - val_mse: 0.4336
# Epoch 3/150
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2144 - mse: 0.2144 - val_loss: 0.4382 - val_mse: 0.4382
# Epoch 4/150
# 157/157 [==============================] - 0s 1ms/step - loss: 0.2129 - mse: 0.2129 - val_loss: 0.4384 - val_mse: 0.4384
# Epoch 5/150
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2115 - mse: 0.2115 - val_loss: 0.4506 - val_mse: 0.4506
# Epoch 6/150
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2104 - mse: 0.2104 - val_loss: 0.4332 - val_mse: 0.4332
# Epoch 7/150
# 157/157 [==============================] - 0s 1ms/step - loss: 0.2092 - mse: 0.2092 - val_loss: 0.4445 - val_mse: 0.4445
# Epoch 8/150
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2081 - mse: 0.2081 - val_loss: 0.4343 - val_mse: 0.4343
# Epoch 9/150
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2070 - mse: 0.2070 - val_loss: 0.4370 - val_mse: 0.4370
# Epoch 10/150
# 157/157 [==============================] - 0s 1ms/step - loss: 0
150
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0774 - mse: 0.0774 - val_loss: 0.0891 - val_mse: 0.0891
# Epoch 143/150
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0769 - mse: 0.0769 - val_loss: 0.0794 - val_mse: 0.0794
# Epoch 144/150
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0769 - mse: 0.0769 - val_loss: 0.0771 - val_mse: 0.0771
# Epoch 145/150
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0762 - mse: 0.0762 - val_loss: 0.0851 - val_mse: 0.0851
# Epoch 146/150
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0768 - mse: 0.0768 - val_loss: 0.0804 - val_mse: 0.0804
# Epoch 147/150
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0759 - mse: 0.0759 - val_loss: 0.1019 - val_mse: 0.1019
# Epoch 148/150
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0760 - mse: 0.0760 - val_loss: 0.0776 - val_mse: 0.0776
# Epoch 149/150
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0757 - mse: 0.0757 - val_loss: 0.0791 - val_mse: 0.0791
# Epoch 150/150
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0756 - mse: 0.0756 - val_loss: 0.0778 - val_mse: 0.0778

# %%
# evaluate model
score = model2.evaluate(data_valid, z_valid, batch_size=32, verbose=0)
print("mse on validation set = ", score[1])
score = model2.evaluate(data_valid, z_target, batch_size=32, verbose=0)
print("mse on target set = ", score[1])
# Out:
# mse on validation set =  0.07776005566120148
# mse on target set =  0.014240984804928303

# %%
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('Model loss funtion during training')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.grid(True)
plt.show()

# %%
x_predicted2 = np.random.uniform(-1.5, 1.5, nvalid)
y_predicted2 = np.random.uniform(-1.5, 1.5, nvalid)
data_predicted2 = np.zeros((nvalid,2))
for k in range(nvalid):
    data_predicted2[k,0] = x_predicted2[k]
    data_predicted2[k,1] = y_predicted2[k]

z_predicted2 = model2.predict(data_predicted2)

# %% [markdown]
# Both models give similar results: mse on validation set is $\approx 0.07-0.08$, mse on target set is always between $\approx 0.009$ and $\approx 0.025$. However, more epochs are needed to train the second model (150 vs 100). As can be noticed comparing the two graphs below, predictions seem correct even if they do not perfectly fit the target function.

# %%
# Make data
X = x_valid
Y = y_valid
X, Y = np.meshgrid(X, Y)
R = (X**2 + Y**2)
Z = np.sin(R)

###########FIRST MODEL ####################################
fig = plt.figure(figsize=(9,9))
ax = fig.gca(projection='3d')
# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap="Blues",
                       linewidth=0, antialiased=False)
## Add points
ax.scatter(x_predicted1, y_predicted1, z_predicted1 , color="aqua", label = "Predicted - first model")
ax.set_xlabel("x",size=13)
ax.set_ylabel("y",size=13)
ax.set_title("Predictions vs target function - first model", size=13)
ax.legend(loc="upper right", fontsize=13)
ax.view_init(15, 20)
# Add a color bar which maps values to colors
fig.colorbar(surf, shrink=0.5, aspect=5)

#############2 MODEL #######################################
fig2= plt.figure(figsize=(9,9))
ax2 = fig2.gca(projection='3d')
# Plot the surface.
surf2 = ax2.plot_surface(X, Y, Z, cmap="Blues",
                       linewidth=0, antialiased=False)
## Add points
ax2.scatter(x_predicted2, y_predicted2, z_predicted2 , color="aqua", label = "Predicted - second model")
ax2.set_xlabel("x",size=13)
ax2.set_ylabel("y",size=13)
ax2.set_title("Predictions vs target function - second model", size=13)
ax2.legend(loc="upper right", fontsize=13)
ax2.view_init(15, 20)
# Add a color bar which maps values to colors
fig2.colorbar(surf, shrink=0.5, aspect=5)
plt.show()
