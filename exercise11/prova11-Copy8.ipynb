# %% [markdown]
# ## Exericise 11
#
# ### 11.1

# %% [markdown]
# The aim of exercise 11.1 is to fit a linear function $f(x)=2x+1$ using a single neuron neural network.
# At first, the dataset for training and testing are created:
# 1. *training set*: measures used to train the model and optimize regression parameters. Points in this set are obtained by adding a gaussian noise to the linear target function,
# 2. *validation set* (10% of the training set): to test the model accuracy on a separate set not involved in the training process. Like the training set, this is evaluated from linear target function + gaussian noise with same $\sigma$ as in the training set,
# 3. *target set*: the actual target function without the gaussian noise. The model accuracy is evaluated on this set as well.
#
# The following graph reports the three dataset as an example, using 100 points for the training set, 10 points for the validation and target set (the latter is represented as a straight line, the other two as scatterplots).

# %%
### importing libraries
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects
#from tensorflow.keras.callbacks import EarlyStopping

# %%
# target parameters of f(x) = m*x + b
m = 2 # slope
b = 1 # intersect

# %%
# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 100)
x_valid = np.random.uniform(-1, 1, 10)
x_valid.sort()
y_target = m * x_valid + b # ideal (target) linear function

sigma = 0.5 # noise standard deviation
y_train = np.random.normal(m * x_train + b, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(m * x_valid + b, sigma)

# %%
# plot training and target dataset
plt.figure(figsize=(9,6))
plt.plot(x_valid, y_target, color = "maroon", label = "Target function")
plt.scatter(x_valid, y_valid, color='magenta', s=30, label="Validation set")
plt.scatter(x_train, y_train, color = "darkorange", s=15, label="Training set")
plt.xlabel("x",size=13)
plt.ylabel("y",size=13)
plt.title("Training and validation sets and target function")
plt.legend(loc="lower right", fontsize=13)
plt.grid(True); plt.show()

# %% [markdown]
# This first part of Lecture 11 focuses on three parameters: $N_{train}$ (the training set size), $\sigma$ (the gaussian noise standard deviation applied on the training and validation sets), $N_{epochs}$ (an epoch is a single run of the NN during the training phase). The mean sqaured error was used as loss function in the whole exercise.
#
# At first these parameters were set to: $N_{train} = 100$, $\sigma=0$, $N_{epochs}=30$. With this parameters setting, the loss function evaluated on the validation set resulted to be $\approx 0.3$. After that, the training set size $N_{train}$, $\sigma$ and the number of epochs $N_{epochs}$ were varied to see how the model is related to these parameters and to improve the fitting. The script was simply run several times varying manually $N_{train}$, $\sigma$ and $N_{epochs}$ to find the best combination of the three parameters. Loss function on the validation and on the target set were taken into account to evaluate the fitting (loss function on the validation data was considered as well in order to avoid overfitting).

# %% [markdown]
# **Varying $\sigma$**: $ \ \ \ $ ($N_{epochs}=40$, $N_{train}=100$)
#
# |sigma|predicted m|predicted b|loss on validation set|loss on target set|
# |---|---|---|---|---|
# |0.1|1.9332693|1.005875|0.010002939961850643|0.0011858774814754725|
# |0.3|2.0103765|1.0422844|0.07495731115341187|0.001961078029125929|
# |0.5|2.0715578|1.0032238|0.15864932537078857|0.001555219292640686|
# |0.7|1.975122|0.86201894|0.4242778718471527|0.020328989252448082|
# |0.9|2.0787158|0.9541927|0.8266009092330933|0.0027085761539638042|
# |1.3|1.9195483|0.6753314|0.862949013710022|0.11573337018489838|
#
# As expected, the loss function increases with $\sigma$ (the more the training data are spread, the more difficult it is to evaluate m and b). However, incresing the number of epochs it is possible to reduce the loss function on the target set (loss on validation set doesn't improve, this may be due to the fact that the validation set is spread as well).
#
# $ \\ $
#
# **Varying $N_{train}$**: $ \ \ \ $   ($N_{epochs}=40$, $\sigma=0.3$, $batch = 32$, validation set size always 10% of the training set size)
#
# |training set size|predicted m|predicted b|loss on validation set| loss on target set|
# |---|---|---|---|---|
# |70|2.0668828|1.028657|0.11259597539901733|0.0034668243024498224|
# |120|2.103306|1.0182844|0.09926555305719376|0.0027775231283158064|
# |200|2.0409226|0.9646509|0.10246913135051727|0.0020201418083161116|
# |500|2.0328834|0.97006744|0.09979042828083039|0.0013439443736569957|
# |1000|2.0022569|1.0069656|0.07386541679501533|4.926809080643579e-05|
#
# In general, predctions seem to improve increaing $N_{train}$, even if the loss function on the validation/target seem to depend more on $\sigma$ rather than $N_{train}$.
#
# $ \\ $
#
# **Varying $N_{epochs}$**: $ \ \ \ $   ($N_{train}= 500 $, $\sigma=0.3$, $batch = 32$, validation set size always 10% of the training set size)
#
# |# epochs|predicted m|predicted b|loss on validation set| loss on target set|
# |---|---|---|---|---|
# |50|2.031459|0.96656036|0.10073151409626008|0.0015440493111964315|
# |60|2.0192769|0.97956055|0.0599472776055336|0.000577559914381709|
# |75|2.0210502|1.0103799|0.0705984503030777|0.0002262158808298409|
# |100|1.9751853|0.9959381|0.08684590220451355|0.00020237264805473388|
# |200|1.9968362|0.9857125|0.09561826169490814|0.00020259216660633683|
#
# While the loss function on the target set decreases with $N_{epochs}$, the loss on the validation turns out to be higher for $N_{epochs} > \approx 60$. This could be due to overfitting.
#
# In conclusion, in the rest of the exercise 11.1 the parameters were set to: $\sigma = 0.3$, $N_{train} = 800$, $N_{epochs}=45$.

# %%
#compose the NN model
model = tf.keras.Sequential()
## one layer with one input
model.add(Dense(1, input_shape=(1,)))
# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
np.random.seed(0)
# generate training inputs
x_train = np.random.uniform(-1, 1, 800)
x_valid = np.random.uniform(-1, 1, 80)
x_valid.sort()
y_target = m * x_valid + b # ideal (target) linear function

sigma = 0.3 # noise standard deviation
y_train = np.random.normal(m * x_train + b, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(m * x_valid + b, sigma)
    
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=45,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Train on 800 samples, validate on 80 samples
# Epoch 1/45
# 800/800 [==============================] - 1s 1ms/sample - loss: 0.9790 - mse: 0.9790 - val_loss: 0.6883 - val_mse: 0.6883
# Epoch 2/45
# 800/800 [==============================] - 0s 218us/sample - loss: 0.5032 - mse: 0.5032 - val_loss: 0.3830 - val_mse: 0.3830
# Epoch 3/45
# 800/800 [==============================] - 0s 206us/sample - loss: 0.3030 - mse: 0.3030 - val_loss: 0.2461 - val_mse: 0.2461
# Epoch 4/45
# 800/800 [==============================] - 0s 195us/sample - loss: 0.2108 - mse: 0.2108 - val_loss: 0.1801 - val_mse: 0.1801
# Epoch 5/45
# 800/800 [==============================] - 0s 201us/sample - loss: 0.1636 - mse: 0.1636 - val_loss: 0.1441 - val_mse: 0.1441
# Epoch 6/45
# 800/800 [==============================] - 0s 202us/sample - loss: 0.1367 - mse: 0.1367 - val_loss: 0.1229 - val_mse: 0.1229
# Epoch 7/45
# 800/800 [==============================] - 0s 197us/sample - loss: 0.1200 - mse: 0.1200 - val_loss: 0.1093 - val_mse: 0.1093
# Epoch 8/45
# 800/800 [==============================] - 0s 185us/sample - loss: 0.1090 - mse: 0.1090 - val_loss: 0.1005 - val_mse: 0.1005
# Epoch 9/45
# 800/800 [==============================] - 0s 177us/sample - loss: 0.1016 - mse: 0.1016 - val_loss: 0.0945 - val_mse: 0.0945
# Epoch 10/45
# 800/800 [==============================] - 0s 224us/sample - loss: 0.0964 - mse: 0.0964 - val_loss: 0.0903 - val_mse: 0.0903
# Epoch 11/45
# 800/800 [==============================] - 0s 218us/sample - loss: 0.0928 - mse: 0.0928 - val_loss: 0.0874 - val_mse: 0.0874
# Epoch 12/45
# 800/800 [==============================] - 0s 183us/sample - loss: 0.0902 - mse: 0.0902 - val_loss: 0.0853 - val_mse: 0.0853
# Epoch 13/45
# 800/800 [==============================] - 0s 174us/sample - loss: 0.0883 - mse: 0.0883 - val_loss: 0.0839 - val_mse: 0.0839
# Epoch 14/45
# 800/800 [==============================] - 0s 185us/sample - loss: 0.0871 - mse: 0.0871 - val_loss: 0.0829 - val_mse: 0.0829
# Epoch 15/45
# 800/800 [==============================] - 0s 180us/sample - loss: 0.0862 - mse: 0.0862 - val_loss: 0.0822 - val_mse: 0.0822
# Epoch 16/45
# 800/800 [==============================] - 0s 183us/sample - loss: 0.0855 - mse: 0.0855 - val_loss: 0.0816 - val_mse: 0.0816
# Epoch 17/45
# 800/800 [==============================] - 0s 201us/sample - loss: 0.0851 - mse: 0.0851 - val_loss: 0.0813 - val_mse: 0.0813
# Epoch 18/45
# 800/800 [==============================] - 0s 213us/sample - loss: 0.0848 - mse: 0.0848 - val_loss: 0.0810 - val_mse: 0.0810
# Epoch 19/45
# 800/800 [==============================] - 0s 199us/sample - loss: 0.0846 - mse: 0.0846 - val_loss: 0.0809 - val_mse: 0.0809
# Epoch 20/45
# 800/800 [==============================] - 0s 178us/sample - loss: 0.0844 - mse: 0.0844 - val_loss: 0.0808 - val_mse: 0.0808
# Epoch 21/45
# 800/800 [==============================] - 0s 207us/sample - loss: 0.0843 - mse: 0.0843 - val_loss: 0.0807 - val_mse: 0.0807
# Epoch 22/45
# 800/800 [==============================] - 0s 218us/sample - loss: 0.0842 - mse: 0.0842 - val_loss: 0.0806 - val_mse: 0.0806
# Epoch 23/45
# 800/800 [==============================] - 0s 193us/sample - loss: 0.0842 - mse: 0.0842 - val_loss: 0.0806 - val_mse: 0.0806
# Epoch 24/45
# 800/800 [==============================] - 0s 198us/sample - loss: 0.0841 - mse: 0.0841 - val_loss: 0.0806 - val_mse: 0.0806
# Epoch 25/45
# 800/800 [==============================] - 0s 179us/sample - loss: 0.0841 - mse: 0.0841 - val_loss: 0.0806 - val_mse: 0.0806
# Epoch 26/45
# 800/800 [==============================] - 0s 192us/sample - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 27/45
# 800/800 [==============================] - 0s 191us/sample - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 28/45
# 800/800 [==============================] - 0s 194us/sample - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 29/45
# 800/800 [==============================] - 0s 188us/sample - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 30/45
# 800/800 [==============================] - 0s 196us/sample - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 31/45
# 800/800 [==============================] - 0s 187us/sample - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 32/45
# 800/800 [==============================] - 0s 198us/sample - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 33/45
# 800/800 [==============================] - 0s 208us/sample - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 34/45
# 800/800 [==============================] - 0s 198us/sample - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 35/45
# 800/800 [==============================] - 0s 197us/sample - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 36/45
# 800/800 [==============================] - 0s 197us/sample - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 37/45
# 800/800 [==============================] - 0s 205us/sample - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 38/45
# 800/800 [==============================] - 0s 205us/sample - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 39/45
# 800/800 [==============================] - 0s 204us/sample - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 40/45
# 800/800 [==============================] - 0s 198us/sample - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 41/45
# 800/800 [==============================] - 0s 209us/sample - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 42/45
# 800/800 [==============================] - 0s 199us/sample - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 43/45
# 800/800 [==============================] - 0s 203us/sample - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 44/45
# 800/800 [==============================] - 0s 199us/sample - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 45/45
# 800/800 [==============================] - 0s 296us/sample - loss: 0.0840 - mse: 0.0840 - val_loss: 0.0805 - val_mse: 0.0805

# %%
# evaluate model
score = model2.evaluate(x_valid, y_valid, batch_size=32, verbose=0)

# print performance
print('Test loss on validation set:', score[0])
print('Test accuracy (= metrics) on validation set:', score[1])

# evaluate model with the exact curve
score = model2.evaluate(x_valid, y_target, batch_size=32, verbose=0)

# print performance
print('Test loss on target set:', score[0])
print('Test accuracy (=metrics) on target set:', score[1])
# Out:
# Test loss on validation set: 0.8551745414733887
# Test accuracy (= metrics) on validation set: 0.8551745414733887
# Test loss on target set: 0.8408718109130859
# Test accuracy (=metrics) on target set: 0.8408718109130859

# %% [markdown]
# The two graphs below show the result obtained with these parameters: the loss function trend during the training and predictions on a new set of data compared to the exact function.

# %%
##-> 45 epochs, sigma 0.3,  ntrain = 800
plt.figure(figsize=(9,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss',size=13)
plt.ylabel('Loss',size=13)
plt.xlabel('Epoch',size=13)
plt.legend(['Train', 'Test'], loc='best',fontsize=13)
plt.grid(True)
plt.show()

# %%
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)

plt.figure(figsize=(9,6))
plt.scatter(x_predicted, y_predicted, color = "r",s=20, label = "Predicted")
plt.plot(x_valid, y_target, label = "Target function")
plt.xlabel("x",size=13)
plt.ylabel("y",size=13)
plt.title("Predictions vs target function")
plt.legend(loc="lower right", fontsize=13)
plt.grid(True); plt.show()

# %% [markdown]
# ### 11.2

# %% [markdown]
# In this section the function to fit is: $f(x)=4-3x-2x^2+3x^3$ for $x \in [-1,1]$, focusing on the following parameters:
# - the number of layers $N_L$,
# - the number of neurons in each layer $N_n$,
# - the activation function,
# - the optimizer,
# - the loss function.

# %%
def func(x):
    return 4 - 3*x -2*(x**2) + 3*(x**3)

# %%
## training and validation sets (n train is still 800)
np.random.seed(0)
# generate training inputs
x_train = np.random.uniform(-1, 1, 500)
x_valid = np.random.uniform(-1, 1, 50)
x_valid.sort()
y_target = func(x_valid) # ideal (target) linear function

sigma = 0.3 # noise standard deviation
y_train = np.random.normal(func(x_train), sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(func(x_valid), sigma)

# %%
plt.figure(figsize=(9,6))
plt.plot(x_valid, y_target, color = "red", label = "Target function")
plt.scatter(x_valid, y_valid, color='midnightblue', s=30, label="Validation set")
plt.scatter(x_train, y_train, color = "dodgerblue", s=10, label="Training set")
plt.xlabel("x",size=13)
plt.ylabel("y",size=13)
plt.title("Training set, validation set and target function")
plt.legend(loc="upper right", fontsize=13)
plt.grid(True); plt.show()

# %% [markdown]
# #### Number of layers & nodes per layer
#
# In this phase the number of layers and nodes were varied looking for the best combination of the two. This was at first evalued using the accuracy (set to mse) on target and validation sets.

# %%
from itertools import product
models = [] 
Nl = [10,5,2] ## numero di layer
Nn = [3,10,25,50] ## numero di nodi
acc_val = []
acc_tar = []

for l,n in product(Nl, Nn): 
    model = tf.keras.Sequential()
    model.add(Dense(n, input_shape=(1,),activation="relu")) ## primo layer
    for i in range(l-1):  
        model.add(Dense(n, activation="relu"))
    model.add(Dense(1,activation="elu"))
    model.compile(optimizer='sgd', loss='mse', metrics=['mse'])
    model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=45,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid), verbose=0)
    models.append(model) ## nel vettore di modelli dopo il training
    print("model with " , l, " layers with ", n, " nodes each")
    # evaluate model
    score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=0)
    acc_val.append(score[1])
    print("mse on validation set = ", score[1])
    score = model.evaluate(x_valid, y_target, batch_size=32, verbose=0)
    acc_tar.append(score[1])
    print("mse on target set = ", score[1])
# Out:
# model with  10  layers with  3  nodes each
# mse on validation set =  1.0099948644638062
# mse on target set =  0.9929425120353699
# model with  10  layers with  10  nodes each
# mse on validation set =  0.19723279774188995
# mse on target set =  0.10425441712141037
# model with  10  layers with  25  nodes each
# mse on validation set =  0.08919373154640198
# mse on target set =  0.015796080231666565
# model with  10  layers with  50  nodes each
# mse on validation set =  0.105415478348732
# mse on target set =  0.00738963857293129
# model with  5  layers with  3  nodes each
# mse on validation set =  1.000991940498352
# mse on target set =  0.9842583537101746
# model with  5  layers with  10  nodes each
# mse on validation set =  0.11454568803310394
# mse on target set =  0.025361742824316025
# model with  5  layers with  25  nodes each
# mse on validation set =  0.08480299264192581
# mse on target set =  0.014292234554886818
# model with  5  layers with  50  nodes each
# mse on validation set =  0.18333645164966583
# mse on target set =  0.05994359031319618
# model with  2  layers with  3  nodes each
# mse on validation set =  0.21750618517398834
# mse on target set =  0.16159172356128693
# model with  2  layers with  10  nodes each
# mse on validation set =  0.17290863394737244
# mse on target set =  0.13002139329910278
# model with  2  layers with  25  nodes each
# mse on validation set =  0.11545237898826599
# mse on target set =  0.06408268958330154
# model with  2  layers with  50  nodes each
# mse on validation set =  0.11328153312206268
# mse on target set =  0.06560151278972626

# %%
acc_val2 = np.round(acc_val, decimals=3)
acc_tar2 = np.round(acc_tar, decimals=3)

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
acc_val2 = np.reshape(acc_val2,(3,4))
acc_tar2 = np.reshape(acc_tar2,(3,4))

fig, (ax1,ax2) = plt.subplots(1,2, figsize=(20,10))
divider = make_axes_locatable(ax)
cax = divider.append_axes('right', size='5%', pad=0.05)

im1 = ax1.imshow(acc_val2)
ax1.set_xticks(np.arange(len(Nn)))
ax1.set_yticks(np.arange(len(Nl)))
ax1.set_xticklabels(Nn,size=20)
ax1.set_yticklabels(Nl,size=20)
ax1.set_xlabel("Number of nodes per layer",size=20)
ax1.set_ylabel("Number of layers",size=20)
ax1.set_title("Accuracy values on validation set", size=20)
plt.setp(ax1.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

for i in range(len(Nl)):
    for j in range(len(Nn)):
        text = ax1.text(j, i, acc_val2[i, j],
                       ha="center", va="center", color="w", size=20)

im2 = ax2.imshow(acc_tar2)
ax2.set_xticks(np.arange(len(Nn)))
ax2.set_yticks(np.arange(len(Nl)))
ax2.set_xticklabels(Nn,size=20)
ax2.set_yticklabels(Nl,size=20)
ax2.set_xlabel("Number of nodes per layer",size=20)
ax2.set_ylabel("Number of layers",size=20)
ax2.set_title("Accuracy values on target set", size=20)
plt.setp(ax2.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

for i in range(len(Nl)):
    for j in range(len(Nn)):
        text = ax2.text(j, i, acc_tar2[i, j],
                       ha="center", va="center", color="w",size=20)
        
fig.colorbar(im, cax=cax, orientation='vertical')

# %% [markdown]
# The best models with the parameters were applied on new data and predictions were compared to the target function:
# - 10 layers, 25 nodes,
# - 10 layers, 50 nodes,
# - 5 layers, 10 nodes,
# - 5 layers, 25 nodes.
#
# It is possible to notice that the NN isn't able to predict correclty the target function beyond the training interval.

# %%
x_predicted = np.random.uniform(-1.5, 1.5, 200)
y_predicted2 = models[2].predict(x_predicted)
y_predicted3 = models[3].predict(x_predicted)
y_predicted5 = models[5].predict(x_predicted)
y_predicted6 = models[6].predict(x_predicted)

plt.figure(figsize=(9,6))
plt.scatter(x_predicted, y_predicted2, s=15, label = "Predicted - 10 layers, 25 nodes")
plt.scatter(x_predicted, y_predicted3, s=15, label = "Predicted - 10 layers, 50 nodes")
plt.scatter(x_predicted, y_predicted5, s=15, label = "Predicted - 5 layers, 10 nodes")
plt.scatter(x_predicted, y_predicted6, s=15, label = "Predicted - 5 layers, 25 nodes")
plt.plot(x_valid, y_target, label = "Target function")
plt.xlabel("x",size=13)
plt.ylabel("y",size=13)
plt.title("Predictions vs target function", size=13)
plt.legend(loc="upper right", fontsize=11.5)
plt.grid(True); plt.show()

# %% [markdown]
# The combinations that best fits the target function seem to be either 10 layers + 25 nodes or 10 layers + 50 nodes.
#
# #### Activation functions
#
# In this part various models with different activations functions (the final activation function is always *elu*) were tested. All models have 10 layers and 25 nodes. The activation function with the lowest mse on the validation and target set (*elu*, *selu*, *relu*, *tanh*) are plotted in the graphs below.

# %%
## open bounds activation functions: elu, selu, relu, softplus
models2 = []
acc_val2 = []
acc_tar2 = []
act = ["elu", "relu", "selu", "softplus"]
##elu
n = 25
for a in act:
    model = tf.keras.Sequential()
    model.add(Dense(n, input_shape=(1,),activation=a)) ## primo layer
    for i in range(9):  
        model.add(Dense(n, activation=a))
    model.add(Dense(1,activation='elu'))
    model.compile(optimizer='sgd', loss='mse', metrics=['mse'])
    model.fit(x=x_train, y=y_train, 
              batch_size=32, epochs=45,
              shuffle=True, # a good idea is to shuffle input before at each epoch
              validation_data=(x_valid, y_valid))
    models2.append(model) ## nel vettore di modelli dopo il training
    print("model with ", a)
     # evaluate model
    score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=0)
    print("mse on validation set = ", score[1])
    acc_val2.append(score[1])
    score = model.evaluate(x_valid, y_target, batch_size=32, verbose=0)
    print("mse on target set = ", score[1])
    acc_tar2.append(score[1])
# Out:
# Epoch 1/45
# 16/16 [==============================] - 0s 15ms/step - loss: 2.9718 - mse: 2.9718 - val_loss: 0.6457 - val_mse: 0.6457
# Epoch 2/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4985 - mse: 0.4985 - val_loss: 0.6474 - val_mse: 0.6474
# Epoch 3/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4727 - mse: 0.4727 - val_loss: 0.5942 - val_mse: 0.5942
# Epoch 4/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4462 - mse: 0.4462 - val_loss: 0.5890 - val_mse: 0.5890
# Epoch 5/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4327 - mse: 0.4327 - val_loss: 0.5450 - val_mse: 0.5450
# Epoch 6/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4040 - mse: 0.4040 - val_loss: 0.4880 - val_mse: 0.4880
# Epoch 7/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3620 - mse: 0.3620 - val_loss: 0.4637 - val_mse: 0.4637
# Epoch 8/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3440 - mse: 0.3440 - val_loss: 0.3171 - val_mse: 0.3171
# Epoch 9/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2471 - mse: 0.2471 - val_loss: 0.2600 - val_mse: 0.2600
# Epoch 10/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1946 - mse: 0.1946 - val_loss: 0.1810 - val_mse: 0.1810
# Epoch 11/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1801 - mse: 0.1801 - val_loss: 0.2509 - val_mse: 0.2509
# Epoch 12/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1878 - mse: 0.1878 - val_loss: 0.1365 - val_mse: 0.1365
# Epoch 13/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1862 - mse: 0.1862 - val_loss: 0.1389 - val_mse: 0.1389
# Epoch 14/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1195 - mse: 0.1195 - val_loss: 0.1435 - val_mse: 0.1435
# Epoch 15/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1759 - mse: 0.1759 - val_loss: 0.1106 - val_mse: 0.1106
# Epoch 16/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1734 - mse: 0.1734 - val_loss: 0.0898 - val_mse: 0.0898
# Epoch 17/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1360 - mse: 0.1360 - val_loss: 0.1206 - val_mse: 0.1206
# Epoch 18/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1376 - mse: 0.1376 - val_loss: 0.0911 - val_mse: 0.0911
# Epoch 19/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1162 - mse: 0.1162 - val_loss: 0.1047 - val_mse: 0.1047
# Epoch 20/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1149 - mse: 0.1149 - val_loss: 0.0905 - val_mse: 0.0905
# Epoch 21/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1626 - mse: 0.1626 - val_loss: 0.0991 - val_mse: 0.0991
# Epoch 22/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1345 - mse: 0.1345 - val_loss: 0.2044 - val_mse: 0.2044
# Epoch 23/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1479 - mse: 0.1479 - val_loss: 0.1052 - val_mse: 0.1052
# Epoch 24/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1220 - mse: 0.1220 - val_loss: 0.0839 - val_mse: 0.0839
# Epoch 25/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1140 - mse: 0.1140 - val_loss: 0.1364 - val_mse: 0.1364
# Epoch 26/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1360 - mse: 0.1360 - val_loss: 0.0865 - val_mse: 0.0865
# Epoch 27/45
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1162 - mse: 0.1162 - val_loss: 0.0975 - val_mse: 0.0975
# Epoch 28/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1153 - mse: 0.1153 - val_loss: 0.1252 - val_mse: 0.1252
# Epoch 29/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1047 - mse: 0.1047 - val_loss: 0.0953 - val_mse: 0.0953
# Epoch 30/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1007 - mse: 0.1007 - val_loss: 0.2213 - val_mse: 0.2213
# Epoch 31/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1273 - mse: 0.1273 - val_loss: 0.0908 - val_mse: 0.0908
# Epoch 32/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1113 - mse: 0.1113 - val_loss: 0.1226 - val_mse: 0.1226
# Epoch 33/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1183 - mse: 0.1183 - val_loss: 0.1478 - val_mse: 0.1478
# Epoch 34/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1163 - mse: 0.1163 - val_loss: 0.1059 - val_mse: 0.1059
# Epoch 35/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1108 - mse: 0.1108 - val_loss: 0.1449 - val_mse: 0.1449
# Epoch 36/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1190 - mse: 0.1190 - val_loss: 0.1362 - val_mse: 0.1362
# Epoch 37/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1095 - mse: 0.1095 - val_loss: 0.1684 - val_mse: 0.1684
# Epoch 38/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1000 - mse: 0.1000 - val_loss: 0.1008 - val_mse: 0.1008
# Epoch 39/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1016 - mse: 0.1016 - val_loss: 0.1154 - val_mse: 0.1154
# Epoch 40/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1098 - mse: 0.1098 - val_loss: 0.1711 - val_mse: 0.1711
# Epoch 41/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1122 - mse: 0.1122 - val_loss: 0.1970 - val_mse: 0.1970
# Epoch 42/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1169 - mse: 0.1169 - val_loss: 0.1410 - val_mse: 0.1410
# Epoch 43/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1013 - mse: 0.1013 - val_loss: 0.1188 - val_mse: 0.1188
# Epoch 44/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1060 - mse: 0.1060 - val_loss: 0.0890 - val_mse: 0.0890
# Epoch 45/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1103 - mse: 0.1103 - val_loss: 0.1000 - val_mse: 0.1000
# model with  elu
# mse on validation set =  0.10001523792743683
# mse on target set =  0.014490475878119469
# Epoch 1/45
# 16/16 [==============================] - 0s 15ms/step - loss: 7.6386 - mse: 7.6386 - val_loss: 3.2073 - val_mse: 3.2073
# Epoch 2/45
# 16/16 [==============================] - 0s 3ms/step - loss: 1.5997 - mse: 1.5997 - val_loss: 1.0249 - val_mse: 1.0249
# Epoch 3/45
# 16/16 [==============================] - 0s 3ms/step - loss: 1.0926 - mse: 1.0926 - val_loss: 0.9772 - val_mse: 0.9772
# Epoch 4/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.0187 - mse: 1.0187 - val_loss: 0.8868 - val_mse: 0.8868
# Epoch 5/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.9329 - mse: 0.9329 - val_loss: 0.7923 - val_mse: 0.7923
# Epoch 6/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.7888 - mse: 0.7888 - val_loss: 0.7151 - val_mse: 0.7151
# Epoch 7/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.6164 - mse: 0.6164 - val_loss: 0.6102 - val_mse: 0.6102
# Epoch 8/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4645 - mse: 0.4645 - val_loss: 0.5160 - val_mse: 0.5160
# Epoch 9/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4025 - mse: 0.4025 - val_loss: 0.4834 - val_mse: 0.4834
# Epoch 10/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3691 - mse: 0.3691 - val_loss: 0.4855 - val_mse: 0.4855
# Epoch 11/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3588 - mse: 0.3588 - val_loss: 0.4733 - val_mse: 0.4733
# Epoch 12/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3503 - mse: 0.3503 - val_loss: 0.4601 - val_mse: 0.4601
# Epoch 13/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3429 - mse: 0.3429 - val_loss: 0.4501 - val_mse: 0.4501
# Epoch 14/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3399 - mse: 0.3399 - val_loss: 0.4479 - val_mse: 0.4479
# Epoch 15/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3422 - mse: 0.3422 - val_loss: 0.4684 - val_mse: 0.4684
# Epoch 16/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3204 - mse: 0.3204 - val_loss: 0.4135 - val_mse: 0.4135
# Epoch 17/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3097 - mse: 0.3097 - val_loss: 0.4012 - val_mse: 0.4012
# Epoch 18/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3074 - mse: 0.3074 - val_loss: 0.3828 - val_mse: 0.3828
# Epoch 19/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2939 - mse: 0.2939 - val_loss: 0.3690 - val_mse: 0.3690
# Epoch 20/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2843 - mse: 0.2843 - val_loss: 0.3384 - val_mse: 0.3384
# Epoch 21/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2493 - mse: 0.2493 - val_loss: 0.3110 - val_mse: 0.3110
# Epoch 22/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2601 - mse: 0.2601 - val_loss: 0.2486 - val_mse: 0.2486
# Epoch 23/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2141 - mse: 0.2141 - val_loss: 0.2150 - val_mse: 0.2150
# Epoch 24/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2131 - mse: 0.2131 - val_loss: 0.3553 - val_mse: 0.3553
# Epoch 25/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2457 - mse: 0.2457 - val_loss: 0.2239 - val_mse: 0.2239
# Epoch 26/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1693 - mse: 0.1693 - val_loss: 0.3922 - val_mse: 0.3922
# Epoch 27/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2259 - mse: 0.2259 - val_loss: 0.1318 - val_mse: 0.1318
# Epoch 28/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1459 - mse: 0.1459 - val_loss: 0.1835 - val_mse: 0.1835
# Epoch 29/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1286 - mse: 0.1286 - val_loss: 0.1271 - val_mse: 0.1271
# Epoch 30/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1521 - mse: 0.1521 - val_loss: 0.1318 - val_mse: 0.1318
# Epoch 31/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1596 - mse: 0.1596 - val_loss: 0.2694 - val_mse: 0.2694
# Epoch 32/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1560 - mse: 0.1560 - val_loss: 0.1201 - val_mse: 0.1201
# Epoch 33/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1184 - mse: 0.1184 - val_loss: 0.0967 - val_mse: 0.0967
# Epoch 34/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1459 - mse: 0.1459 - val_loss: 0.1406 - val_mse: 0.1406
# Epoch 35/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1297 - mse: 0.1297 - val_loss: 0.1217 - val_mse: 0.1217
# Epoch 36/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1245 - mse: 0.1245 - val_loss: 0.1367 - val_mse: 0.1367
# Epoch 37/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1487 - mse: 0.1487 - val_loss: 0.1038 - val_mse: 0.1038
# Epoch 38/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0997 - mse: 0.0997 - val_loss: 0.1656 - val_mse: 0.1656
# Epoch 39/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1637 - mse: 0.1637 - val_loss: 0.0998 - val_mse: 0.0998
# Epoch 40/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1163 - mse: 0.1163 - val_loss: 0.1178 - val_mse: 0.1178
# Epoch 41/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1219 - mse: 0.1219 - val_loss: 0.0987 - val_mse: 0.0987
# Epoch 42/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1079 - mse: 0.1079 - val_loss: 0.1387 - val_mse: 0.1387
# Epoch 43/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1030 - mse: 0.1030 - val_loss: 0.2177 - val_mse: 0.2177
# Epoch 44/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1105 - mse: 0.1105 - val_loss: 0.0938 - val_mse: 0.0938
# Epoch 45/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0961 - mse: 0.0961 - val_loss: 0.1295 - val_mse: 0.1295
# model with  relu
# mse on validation set =  0.1294516921043396
# mse on target set =  0.034213822335004807
# Epoch 1/45
# 16/16 [==============================] - 0s 16ms/step - loss: 1.7165 - mse: 1.7165 - val_loss: 0.3893 - val_mse: 0.3893
# Epoch 2/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2944 - mse: 0.2944 - val_loss: 0.2626 - val_mse: 0.2626
# Epoch 3/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3132 - mse: 0.3132 - val_loss: 0.5188 - val_mse: 0.5188
# Epoch 4/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2637 - mse: 0.2637 - val_loss: 0.1609 - val_mse: 0.1609
# Epoch 5/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1718 - mse: 0.1718 - val_loss: 0.1996 - val_mse: 0.1996
# Epoch 6/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1713 - mse: 0.1713 - val_loss: 0.1705 - val_mse: 0.1705
# Epoch 7/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2477 - mse: 0.2477 - val_loss: 0.1400 - val_mse: 0.1400
# Epoch 8/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1903 - mse: 0.1903 - val_loss: 0.1307 - val_mse: 0.1307
# Epoch 9/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1357 - mse: 0.1357 - val_loss: 0.1285 - val_mse: 0.1285
# Epoch 10/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1273 - mse: 0.1273 - val_loss: 0.5397 - val_mse: 0.5397
# Epoch 11/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2319 - mse: 0.2319 - val_loss: 0.2339 - val_mse: 0.2339
# Epoch 12/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1088 - mse: 0.1088 - val_loss: 0.1482 - val_mse: 0.1482
# Epoch 13/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1989 - mse: 0.1989 - val_loss: 0.1560 - val_mse: 0.1560
# Epoch 14/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1662 - mse: 0.1662 - val_loss: 0.2488 - val_mse: 0.2488
# Epoch 15/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1486 - mse: 0.1486 - val_loss: 0.0988 - val_mse: 0.0988
# Epoch 16/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1118 - mse: 0.1118 - val_loss: 0.0903 - val_mse: 0.0903
# Epoch 17/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1446 - mse: 0.1446 - val_loss: 0.1146 - val_mse: 0.1146
# Epoch 18/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1516 - mse: 0.1516 - val_loss: 0.1901 - val_mse: 0.1901
# Epoch 19/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1274 - mse: 0.1274 - val_loss: 0.1095 - val_mse: 0.1095
# Epoch 20/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1206 - mse: 0.1206 - val_loss: 0.1132 - val_mse: 0.1132
# Epoch 21/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1457 - mse: 0.1457 - val_loss: 0.4736 - val_mse: 0.4736
# Epoch 22/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1344 - mse: 0.1344 - val_loss: 0.1031 - val_mse: 0.1031
# Epoch 23/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1063 - mse: 0.1063 - val_loss: 0.1155 - val_mse: 0.1155
# Epoch 24/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1335 - mse: 0.1335 - val_loss: 0.1422 - val_mse: 0.1422
# Epoch 25/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2064 - mse: 0.2064 - val_loss: 0.1086 - val_mse: 0.1086
# Epoch 26/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1199 - mse: 0.1199 - val_loss: 0.1134 - val_mse: 0.1134
# Epoch 27/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1344 - mse: 0.1344 - val_loss: 0.1413 - val_mse: 0.1413
# Epoch 28/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1150 - mse: 0.1150 - val_loss: 0.2697 - val_mse: 0.2697
# Epoch 29/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1257 - mse: 0.1257 - val_loss: 0.1213 - val_mse: 0.1213
# Epoch 30/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1182 - mse: 0.1182 - val_loss: 0.0982 - val_mse: 0.0982
# Epoch 31/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1091 - mse: 0.1091 - val_loss: 0.0869 - val_mse: 0.0869
# Epoch 32/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1467 - mse: 0.1467 - val_loss: 0.0929 - val_mse: 0.0929
# Epoch 33/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1085 - mse: 0.1085 - val_loss: 0.1046 - val_mse: 0.1046
# Epoch 34/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1441 - mse: 0.1441 - val_loss: 0.1463 - val_mse: 0.1463
# Epoch 35/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1010 - mse: 0.1010 - val_loss: 0.1144 - val_mse: 0.1144
# Epoch 36/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1100 - mse: 0.1100 - val_loss: 0.0930 - val_mse: 0.0930
# Epoch 37/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1457 - mse: 0.1457 - val_loss: 0.1558 - val_mse: 0.1558
# Epoch 38/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1181 - mse: 0.1181 - val_loss: 0.1058 - val_mse: 0.1058
# Epoch 39/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1122 - mse: 0.1122 - val_loss: 0.1302 - val_mse: 0.1302
# Epoch 40/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1150 - mse: 0.1150 - val_loss: 0.1269 - val_mse: 0.1269
# Epoch 41/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1118 - mse: 0.1118 - val_loss: 0.0931 - val_mse: 0.0931
# Epoch 42/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1426 - mse: 0.1426 - val_loss: 0.2658 - val_mse: 0.2658
# Epoch 43/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1417 - mse: 0.1417 - val_loss: 0.1776 - val_mse: 0.1776
# Epoch 44/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1041 - mse: 0.1041 - val_loss: 0.1489 - val_mse: 0.1489
# Epoch 45/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1097 - mse: 0.1097 - val_loss: 0.1096 - val_mse: 0.1096
# model with  selu
# mse on validation set =  0.10961756110191345
# mse on target set =  0.04664048179984093
# Epoch 1/45
# 16/16 [==============================] - 0s 16ms/step - loss: 3.0020 - mse: 3.0020 - val_loss: 1.0021 - val_mse: 1.0021
# Epoch 2/45
# 16/16 [==============================] - 0s 3ms/step - loss: 1.1412 - mse: 1.1412 - val_loss: 1.0597 - val_mse: 1.0597
# Epoch 3/45
# 16/16 [==============================] - 0s 3ms/step - loss: 1.1476 - mse: 1.1476 - val_loss: 1.0066 - val_mse: 1.0066
# Epoch 4/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1416 - mse: 1.1416 - val_loss: 0.9970 - val_mse: 0.9970
# Epoch 5/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1434 - mse: 1.1434 - val_loss: 1.0749 - val_mse: 1.0749
# Epoch 6/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1648 - mse: 1.1648 - val_loss: 1.0140 - val_mse: 1.0140
# Epoch 7/45
# 16/16 [==============================] - 0s 3ms/step - loss: 1.1331 - mse: 1.1331 - val_loss: 0.9995 - val_mse: 0.9995
# Epoch 8/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1291 - mse: 1.1291 - val_loss: 1.0766 - val_mse: 1.0766
# Epoch 9/45
# 16/16 [==============================] - 0s 3ms/step - loss: 1.1553 - mse: 1.1553 - val_loss: 1.0347 - val_mse: 1.0347
# Epoch 10/45
# 16/16 [==============================] - 0s 3ms/step - loss: 1.1564 - mse: 1.1564 - val_loss: 1.0451 - val_mse: 1.0451
# Epoch 11/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1494 - mse: 1.1494 - val_loss: 1.0254 - val_mse: 1.0254
# Epoch 12/45
# 16/16 [==============================] - 0s 3ms/step - loss: 1.1424 - mse: 1.1424 - val_loss: 1.0167 - val_mse: 1.0167
# Epoch 13/45
# 16/16 [==============================] - 0s 3ms/step - loss: 1.1567 - mse: 1.1567 - val_loss: 1.0164 - val_mse: 1.0164
# Epoch 14/45
# 16/16 [==============================] - 0s 5ms/step - loss: 1.1372 - mse: 1.1372 - val_loss: 1.0144 - val_mse: 1.0144
# Epoch 15/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1699 - mse: 1.1699 - val_loss: 1.3863 - val_mse: 1.3863
# Epoch 16/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1387 - mse: 1.1387 - val_loss: 1.0131 - val_mse: 1.0131
# Epoch 17/45
# 16/16 [==============================] - 0s 3ms/step - loss: 1.1336 - mse: 1.1336 - val_loss: 1.1182 - val_mse: 1.1182
# Epoch 18/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1433 - mse: 1.1433 - val_loss: 1.1929 - val_mse: 1.1929
# Epoch 19/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1818 - mse: 1.1818 - val_loss: 1.0002 - val_mse: 1.0002
# Epoch 20/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1309 - mse: 1.1309 - val_loss: 1.0708 - val_mse: 1.0708
# Epoch 21/45
# 16/16 [==============================] - 0s 3ms/step - loss: 1.1425 - mse: 1.1425 - val_loss: 1.0535 - val_mse: 1.0535
# Epoch 22/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1659 - mse: 1.1659 - val_loss: 1.0300 - val_mse: 1.0300
# Epoch 23/45
# 16/16 [==============================] - 0s 3ms/step - loss: 1.1574 - mse: 1.1574 - val_loss: 1.0551 - val_mse: 1.0551
# Epoch 24/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1454 - mse: 1.1454 - val_loss: 1.0200 - val_mse: 1.0200
# Epoch 25/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1359 - mse: 1.1359 - val_loss: 1.0013 - val_mse: 1.0013
# Epoch 26/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1523 - mse: 1.1523 - val_loss: 0.9998 - val_mse: 0.9998
# Epoch 27/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1264 - mse: 1.1264 - val_loss: 1.0195 - val_mse: 1.0195
# Epoch 28/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1556 - mse: 1.1556 - val_loss: 1.0205 - val_mse: 1.0205
# Epoch 29/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1394 - mse: 1.1394 - val_loss: 1.0029 - val_mse: 1.0029
# Epoch 30/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1459 - mse: 1.1459 - val_loss: 1.0284 - val_mse: 1.0284
# Epoch 31/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1302 - mse: 1.1302 - val_loss: 1.1137 - val_mse: 1.1137
# Epoch 32/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1455 - mse: 1.1455 - val_loss: 1.0329 - val_mse: 1.0329
# Epoch 33/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1333 - mse: 1.1333 - val_loss: 1.0019 - val_mse: 1.0019
# Epoch 34/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1361 - mse: 1.1361 - val_loss: 1.1458 - val_mse: 1.1458
# Epoch 35/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1597 - mse: 1.1597 - val_loss: 1.0176 - val_mse: 1.0176
# Epoch 36/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1491 - mse: 1.1491 - val_loss: 1.1221 - val_mse: 1.1221
# Epoch 37/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1432 - mse: 1.1432 - val_loss: 1.1062 - val_mse: 1.1062
# Epoch 38/45
# 16/16 [==============================] - 0s 3ms/step - loss: 1.1406 - mse: 1.1406 - val_loss: 1.0027 - val_mse: 1.0027
# Epoch 39/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1472 - mse: 1.1472 - val_loss: 1.0135 - val_mse: 1.0135
# Epoch 40/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1328 - mse: 1.1328 - val_loss: 1.4012 - val_mse: 1.4012
# Epoch 41/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1509 - mse: 1.1509 - val_loss: 1.0171 - val_mse: 1.0171
# Epoch 42/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1321 - mse: 1.1321 - val_loss: 1.0868 - val_mse: 1.0868
# Epoch 43/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1412 - mse: 1.1412 - val_loss: 1.0263 - val_mse: 1.0263
# Epoch 44/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1399 - mse: 1.1399 - val_loss: 1.0326 - val_mse: 1.0326
# Epoch 45/45
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1495 - mse: 1.1495 - val_loss: 1.0210 - val_mse: 1.0210
# model with  softplus
# mse on validation set =  1.02095365524292
# mse on target set =  0.9949501752853394

# %%
## activation functions wth plateau: sigmoid, softsign, tanh, softmax
models3 = []
acc_val3 = []
acc_tar3 = []
act = ["sigmoid", "softsign", "tanh", "softmax"]
##elu
n = 25
for a in act:
    model = tf.keras.Sequential()
    model.add(Dense(n, input_shape=(1,),activation=a)) ## primo layer
    for i in range(9):  
        model.add(Dense(n, activation=a))
    model.add(Dense(1,activation='elu'))
    model.compile(optimizer='sgd', loss='mse', metrics=['mse'])
    model.fit(x=x_train, y=y_train, 
              batch_size=32, epochs=45,
              shuffle=True, # a good idea is to shuffle input before at each epoch
              validation_data=(x_valid, y_valid), verbose=0)
    models3.append(model) ## nel vettore di modelli dopo il training
    print("model with ", a)
     # evaluate model
    score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=0)
    print("mse on validation set = ", score[1])
    acc_val3.append(score[1])
    score = model.evaluate(x_valid, y_target, batch_size=32, verbose=0)
    print("mse on target set = ", score[1])
    acc_tar3.append(score[1])
# Out:
# model with  sigmoid
# mse on validation set =  1.010067343711853
# mse on target set =  0.9929466843605042
# model with  softsign
# mse on validation set =  0.18996524810791016
# mse on target set =  0.09004490077495575
# model with  tanh
# mse on validation set =  0.10092587769031525
# mse on target set =  0.04024849086999893
# model with  softmax
# mse on validation set =  1.009340763092041
# mse on target set =  0.9929134845733643

# %%
# plot
x_predicted = np.random.uniform(-1.5, 1.5, 200)
act = ["elu", "relu", "selu", "tanh"]
plt.figure(figsize=(9,6))

for i in range(3):
    y_predicted = models2[i].predict(x_predicted)
    plt.scatter(x_predicted, y_predicted, s=15, label = "Predicted - 10 layers, 25 nodes - " + act[i])
y_predicted = models3[2].predict(x_predicted)
plt.scatter(x_predicted, y_predicted, s=15, label = "Predicted - 10 layers, 25 nodes - tanh")
plt.plot(x_valid, y_target, label = "Target function")
plt.xlabel("x",size=13)
plt.ylabel("y",size=13)
plt.title("Predictions vs target function", size=13)
plt.legend(loc="upper right", fontsize=10)
plt.grid(True); plt.show()

# %% [markdown]
# #### Optimizers

# %%
n = 25

model1 = tf.keras.Sequential()
model1.add(Dense(n, input_shape=(1,),activation="elu")) ## primo layer
for i in range(9):  
        model1.add(Dense(n, activation="elu"))
model1.add(Dense(1,activation='elu'))
model1.compile(optimizer=keras.optimizers.Adagrad(lr=0.01, epsilon=None, decay=0.0), loss='mse', metrics=['mse'])
model1.fit(x=x_train, y=y_train, 
              batch_size=32, epochs=45,
              shuffle=True, # a good idea is to shuffle input before at each epoch
              validation_data=(x_valid, y_valid))
     # evaluate model
score = model1.evaluate(x_valid, y_valid, batch_size=32, verbose=0)
print("mse on validation set = ", score[1])
score = model1.evaluate(x_valid, y_target, batch_size=32, verbose=0)
print("mse on target set = ", score[1])
# Out:
# Epoch 1/45
# 16/16 [==============================] - 0s 15ms/step - loss: 2.6550 - mse: 2.6550 - val_loss: 0.6228 - val_mse: 0.6228
# Epoch 2/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4695 - mse: 0.4695 - val_loss: 0.6491 - val_mse: 0.6491
# Epoch 3/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4305 - mse: 0.4305 - val_loss: 0.4996 - val_mse: 0.4996
# Epoch 4/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3782 - mse: 0.3782 - val_loss: 0.4056 - val_mse: 0.4056
# Epoch 5/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3386 - mse: 0.3386 - val_loss: 0.3468 - val_mse: 0.3468
# Epoch 6/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3064 - mse: 0.3064 - val_loss: 0.3156 - val_mse: 0.3156
# Epoch 7/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2598 - mse: 0.2598 - val_loss: 0.4233 - val_mse: 0.4233
# Epoch 8/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1884 - mse: 0.1884 - val_loss: 0.2307 - val_mse: 0.2307
# Epoch 9/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1792 - mse: 0.1792 - val_loss: 0.1486 - val_mse: 0.1486
# Epoch 10/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1359 - mse: 0.1359 - val_loss: 0.1636 - val_mse: 0.1636
# Epoch 11/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1422 - mse: 0.1422 - val_loss: 0.1035 - val_mse: 0.1035
# Epoch 12/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1393 - mse: 0.1393 - val_loss: 0.0940 - val_mse: 0.0940
# Epoch 13/45
# 16/16 [==============================] - 0s 7ms/step - loss: 0.1255 - mse: 0.1255 - val_loss: 0.1013 - val_mse: 0.1013
# Epoch 14/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1149 - mse: 0.1149 - val_loss: 0.0944 - val_mse: 0.0944
# Epoch 15/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1124 - mse: 0.1124 - val_loss: 0.1457 - val_mse: 0.1457
# Epoch 16/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1323 - mse: 0.1323 - val_loss: 0.0852 - val_mse: 0.0852
# Epoch 17/45
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1052 - mse: 0.1052 - val_loss: 0.0912 - val_mse: 0.0912
# Epoch 18/45
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1402 - mse: 0.1402 - val_loss: 0.1129 - val_mse: 0.1129
# Epoch 19/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1127 - mse: 0.1127 - val_loss: 0.0888 - val_mse: 0.0888
# Epoch 20/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1167 - mse: 0.1167 - val_loss: 0.1440 - val_mse: 0.1440
# Epoch 21/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1079 - mse: 0.1079 - val_loss: 0.1265 - val_mse: 0.1265
# Epoch 22/45
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1086 - mse: 0.1086 - val_loss: 0.0950 - val_mse: 0.0950
# Epoch 23/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1092 - mse: 0.1092 - val_loss: 0.0901 - val_mse: 0.0901
# Epoch 24/45
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1072 - mse: 0.1072 - val_loss: 0.0839 - val_mse: 0.0839
# Epoch 25/45
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1058 - mse: 0.1058 - val_loss: 0.1280 - val_mse: 0.1280
# Epoch 26/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1092 - mse: 0.1092 - val_loss: 0.0931 - val_mse: 0.0931
# Epoch 27/45
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1042 - mse: 0.1042 - val_loss: 0.0898 - val_mse: 0.0898
# Epoch 28/45
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1074 - mse: 0.1074 - val_loss: 0.1479 - val_mse: 0.1479
# Epoch 29/45
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1087 - mse: 0.1087 - val_loss: 0.0883 - val_mse: 0.0883
# Epoch 30/45
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1048 - mse: 0.1048 - val_loss: 0.1078 - val_mse: 0.1078
# Epoch 31/45
# 16/16 [==============================] - 0s 8ms/step - loss: 0.1025 - mse: 0.1025 - val_loss: 0.1214 - val_mse: 0.1214
# Epoch 32/45
# 16/16 [==============================] - 0s 7ms/step - loss: 0.1011 - mse: 0.1011 - val_loss: 0.1028 - val_mse: 0.1028
# Epoch 33/45
# 16/16 [==============================] - 0s 7ms/step - loss: 0.1031 - mse: 0.1031 - val_loss: 0.0932 - val_mse: 0.0932
# Epoch 34/45
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1034 - mse: 0.1034 - val_loss: 0.1179 - val_mse: 0.1179
# Epoch 35/45
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1083 - mse: 0.1083 - val_loss: 0.1662 - val_mse: 0.1662
# Epoch 36/45
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1082 - mse: 0.1082 - val_loss: 0.1229 - val_mse: 0.1229
# Epoch 37/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1009 - mse: 0.1009 - val_loss: 0.1133 - val_mse: 0.1133
# Epoch 38/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0984 - mse: 0.0984 - val_loss: 0.0992 - val_mse: 0.0992
# Epoch 39/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1025 - mse: 0.1025 - val_loss: 0.1019 - val_mse: 0.1019
# Epoch 40/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0970 - mse: 0.0970 - val_loss: 0.1249 - val_mse: 0.1249
# Epoch 41/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1043 - mse: 0.1043 - val_loss: 0.1357 - val_mse: 0.1357
# Epoch 42/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1040 - mse: 0.1040 - val_loss: 0.0868 - val_mse: 0.0868
# Epoch 43/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1060 - mse: 0.1060 - val_loss: 0.0961 - val_mse: 0.0961
# Epoch 44/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1033 - mse: 0.1033 - val_loss: 0.1535 - val_mse: 0.1535
# Epoch 45/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1004 - mse: 0.1004 - val_loss: 0.0822 - val_mse: 0.0822
# mse on validation set =  0.08221907913684845
# mse on target set =  0.01638016290962696

# %%
n = 25

model2 = tf.keras.Sequential()
model2.add(Dense(n, input_shape=(1,),activation="elu")) ## primo layer
for i in range(9):  
        model2.add(Dense(n, activation="elu"))
model2.add(Dense(1,activation='elu'))
model2.compile(optimizer=keras.optimizers.Adadelta(lr=1.0, rho=0.95, epsilon=None, decay=0.0), loss='mse', metrics=['mse'])
model2.fit(x=x_train, y=y_train, 
              batch_size=32, epochs=45,
              shuffle=True, # a good idea is to shuffle input before at each epoch
              validation_data=(x_valid, y_valid))
     # evaluate model
score = model2.evaluate(x_valid, y_valid, batch_size=32, verbose=0)
print("mse on validation set = ", score[1])
score = model2.evaluate(x_valid, y_target, batch_size=32, verbose=0)
print("mse on target set = ", score[1])
# Out:
# Epoch 1/45
# 16/16 [==============================] - 0s 17ms/step - loss: 4.6079 - mse: 4.6079 - val_loss: 0.9657 - val_mse: 0.9657
# Epoch 2/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5979 - mse: 0.5979 - val_loss: 0.7031 - val_mse: 0.7031
# Epoch 3/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4579 - mse: 0.4579 - val_loss: 0.5733 - val_mse: 0.5733
# Epoch 4/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4267 - mse: 0.4267 - val_loss: 0.6852 - val_mse: 0.6852
# Epoch 5/45
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4780 - mse: 0.4780 - val_loss: 0.5199 - val_mse: 0.5199
# Epoch 6/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4260 - mse: 0.4260 - val_loss: 0.3039 - val_mse: 0.3039
# Epoch 7/45
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2670 - mse: 0.2670 - val_loss: 0.5139 - val_mse: 0.5139
# Epoch 8/45
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2698 - mse: 0.2698 - val_loss: 0.4275 - val_mse: 0.4275
# Epoch 9/45
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2426 - mse: 0.2426 - val_loss: 0.3911 - val_mse: 0.3911
# Epoch 10/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2645 - mse: 0.2645 - val_loss: 0.1746 - val_mse: 0.1746
# Epoch 11/45
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1999 - mse: 0.1999 - val_loss: 0.4234 - val_mse: 0.4234
# Epoch 12/45
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1954 - mse: 0.1954 - val_loss: 0.2904 - val_mse: 0.2904
# Epoch 13/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1998 - mse: 0.1998 - val_loss: 0.2867 - val_mse: 0.2867
# Epoch 14/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1545 - mse: 0.1545 - val_loss: 0.1285 - val_mse: 0.1285
# Epoch 15/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2002 - mse: 0.2002 - val_loss: 0.1050 - val_mse: 0.1050
# Epoch 16/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2143 - mse: 0.2143 - val_loss: 0.5972 - val_mse: 0.5972
# Epoch 17/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1515 - mse: 0.1515 - val_loss: 0.4197 - val_mse: 0.4197
# Epoch 18/45
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2623 - mse: 0.2623 - val_loss: 0.0888 - val_mse: 0.0888
# Epoch 19/45
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1201 - mse: 0.1201 - val_loss: 0.0971 - val_mse: 0.0971
# Epoch 20/45
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1457 - mse: 0.1457 - val_loss: 0.1177 - val_mse: 0.1177
# Epoch 21/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1126 - mse: 0.1126 - val_loss: 0.1334 - val_mse: 0.1334
# Epoch 22/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1017 - mse: 0.1017 - val_loss: 0.1615 - val_mse: 0.1615
# Epoch 23/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1864 - mse: 0.1864 - val_loss: 0.2939 - val_mse: 0.2939
# Epoch 24/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1254 - mse: 0.1254 - val_loss: 0.0940 - val_mse: 0.0940
# Epoch 25/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1574 - mse: 0.1574 - val_loss: 0.0903 - val_mse: 0.0903
# Epoch 26/45
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1235 - mse: 0.1235 - val_loss: 0.0818 - val_mse: 0.0818
# Epoch 27/45
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1157 - mse: 0.1157 - val_loss: 0.1028 - val_mse: 0.1028
# Epoch 28/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1233 - mse: 0.1233 - val_loss: 0.2151 - val_mse: 0.2151
# Epoch 29/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1805 - mse: 0.1805 - val_loss: 0.1765 - val_mse: 0.1765
# Epoch 30/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1476 - mse: 0.1476 - val_loss: 0.3942 - val_mse: 0.3942
# Epoch 31/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1213 - mse: 0.1213 - val_loss: 0.1268 - val_mse: 0.1268
# Epoch 32/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1074 - mse: 0.1074 - val_loss: 0.1467 - val_mse: 0.1467
# Epoch 33/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1184 - mse: 0.1184 - val_loss: 0.1258 - val_mse: 0.1258
# Epoch 34/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1408 - mse: 0.1408 - val_loss: 0.1213 - val_mse: 0.1213
# Epoch 35/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1134 - mse: 0.1134 - val_loss: 0.0934 - val_mse: 0.0934
# Epoch 36/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1603 - mse: 0.1603 - val_loss: 0.1114 - val_mse: 0.1114
# Epoch 37/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1436 - mse: 0.1436 - val_loss: 0.1614 - val_mse: 0.1614
# Epoch 38/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1222 - mse: 0.1222 - val_loss: 0.1815 - val_mse: 0.1815
# Epoch 39/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1483 - mse: 0.1483 - val_loss: 0.2117 - val_mse: 0.2117
# Epoch 40/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1340 - mse: 0.1340 - val_loss: 0.1433 - val_mse: 0.1433
# Epoch 41/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1398 - mse: 0.1398 - val_loss: 0.0944 - val_mse: 0.0944
# Epoch 42/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1315 - mse: 0.1315 - val_loss: 0.0898 - val_mse: 0.0898
# Epoch 43/45
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1173 - mse: 0.1173 - val_loss: 0.0857 - val_mse: 0.0857
# Epoch 44/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1382 - mse: 0.1382 - val_loss: 0.2884 - val_mse: 0.2884
# Epoch 45/45
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1505 - mse: 0.1505 - val_loss: 0.1716 - val_mse: 0.1716
# mse on validation set =  0.17163926362991333
# mse on target set =  0.04993874952197075

# %%
# plot
x_predicted = np.random.uniform(-1.5, 1.5, 200)
y_predicted1 = model1.predict(x_predicted)
y_predicted2 = model2.predict(x_predicted)
y_predicted3 = models2[0].predict(x_predicted)


plt.figure(figsize=(9,6))

plt.scatter(x_predicted, y_predicted1, s=10, label = "Predicted - 10 layers, 25 nodes - Adagrad")
plt.scatter(x_predicted, y_predicted2, s=10, label = "Predicted - 10 layers, 25 nodes - Adadelta")
plt.scatter(x_predicted, y_predicted3, s=10, label = "Predicted - 10 layers, 25 nodes - Sgd")
plt.plot(x_valid, y_target, label = "Target function")
plt.xlabel("x",size=13)
plt.ylabel("y",size=13)
plt.title("Predictions vs target function", size=13)
plt.legend(loc="lower right", fontsize=11)
plt.grid(True); plt.show()

# %% [markdown]
# #### Loss functions
#
# mse, mae, mean_squared_logarithmic_error , logcosh
# tanh relu elu selu
# elu selu

# %%
from itertools import product
n = 25
model_loss = []
accval_loss = []
acctar_loss = []

loss = ["mse", "mae", "msle", "logcosh"]
act = ["tanh", "relu", "elu", "selu"]
act_last = ["elu", "selu"]

for l, a, al in product(loss, act, act_last):
    modelnew = tf.keras.Sequential()
    modelnew.add(Dense(n, input_shape=(1,),activation=a)) ## primo layer
    for i in range(9):  
        modelnew.add(Dense(n, activation=a))
    modelnew.add(Dense(1,activation=al))
    modelnew.compile(optimizer="Sgd", loss=l, metrics=['mse'])
    modelnew.fit(x=x_train, y=y_train, 
                  batch_size=32, epochs=45,
                  shuffle=True, # a good idea is to shuffle input before at each epoch
                  validation_data=(x_valid, y_valid), verbose=0)
    model_loss.append(modelnew)
    print("Model with ", l, "as loss, " , a, " as activation function, ", al, " as activation function in the last layer")
 # evaluate model
    score = modelnew.evaluate(x_valid, y_valid, batch_size=32, verbose=0)
    accval_loss.append(score[1])
    print("mse on validation set = ", score[1])
    score = modelnew.evaluate(x_valid, y_target, batch_size=32, verbose=0)
    print("mse on target set = ", score[1])
    acctar_loss.append(score[1])
# Out:
# Model with  mse as loss,  tanh  as activation function,  elu  as activation function in the last layer
# mse on validation set =  0.11694049835205078
# mse on target set =  0.016518428921699524
# Model with  mse as loss,  tanh  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.09025753289461136
# mse on target set =  0.007448142860084772
# Model with  mse as loss,  relu  as activation function,  elu  as activation function in the last layer
# mse on validation set =  0.14942198991775513
# mse on target set =  0.03708008676767349
# Model with  mse as loss,  relu  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.1781599074602127
# mse on target set =  0.0511559434235096
# Model with  mse as loss,  elu  as activation function,  elu  as activation function in the last layer
# mse on validation set =  0.08839383721351624
# mse on target set =  0.016423877328634262
# Model with  mse as loss,  elu  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.2712709307670593
# mse on target set =  0.1343454271554947
# Model with  mse as loss,  selu  as activation function,  elu  as activation function in the last layer
# mse on validation set =  0.11949653923511505
# mse on target set =  0.01795760542154312
# Model with  mse as loss,  selu  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.0826544538140297
# mse on target set =  0.01003153994679451
# Model with  mae as loss,  tanh  as activation function,  elu  as activation function in the last layer
# mse on validation set =  0.23130632936954498
# mse on target set =  0.1374695748090744
# Model with  mae as loss,  tanh  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.17186997830867767
# mse on target set =  0.05167783424258232
# Model with  mae as loss,  relu  as activation function,  elu  as activation function in the last layer
# mse on validation set =  0.09225007891654968
# mse on target set =  0.024163279682397842
# Model with  mae as loss,  relu  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.3668922483921051
# mse on target set =  0.4032828211784363
# Model with  mae as loss,  elu  as activation function,  elu  as activation function in the last layer
# mse on validation set =  0.11592341214418411
# mse on target set =  0.0211318451911211
# Model with  mae as loss,  elu  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.18717601895332336
# mse on target set =  0.163432314991951
# Model with  mae as loss,  selu  as activation function,  elu  as activation function in the last layer
# mse on validation set =  0.20746473968029022
# mse on target set =  0.1669333428144455
# Model with  mae as loss,  selu  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.18291833996772766
# mse on target set =  0.11731288582086563
# Model with  msle as loss,  tanh  as activation function,  elu  as activation function in the last layer
# mse on validation set =  0.3656843602657318
# mse on target set =  0.311681866645813
# Model with  msle as loss,  tanh  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.5600789189338684
# mse on target set =  0.517406165599823
# Model with  msle as loss,  relu  as activation function,  elu  as activation function in the last layer
# mse on validation set =  0.8671576976776123
# mse on target set =  0.8280129432678223
# Model with  msle as loss,  relu  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.645722508430481
# mse on target set =  0.5988447666168213
# Model with  msle as loss,  elu  as activation function,  elu  as activation function in the last layer
# mse on validation set =  0.5900699496269226
# mse on target set =  0.5487982034683228
# Model with  msle as loss,  elu  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.6094567775726318
# mse on target set =  0.5699245929718018
# Model with  msle as loss,  selu  as activation function,  elu  as activation function in the last layer
# mse on validation set =  0.10479361563920975
# mse on target set =  0.007984700612723827
# Model with  msle as loss,  selu  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.09695863723754883
# mse on target set =  0.010009309276938438
# Model with  logcosh as loss,  tanh  as activation function,  elu  as activation function in the last layer
# mse on validation set =  0.09274442493915558
# mse on target set =  0.03264308348298073
# Model with  logcosh as loss,  tanh  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.12421802431344986
# mse on target set =  0.06335002928972244
# Model with  logcosh as loss,  relu  as activation function,  elu  as activation function in the last layer
# mse on validation set =  0.16833466291427612
# mse on target set =  0.11914821714162827
# Model with  logcosh as loss,  relu  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.3758034110069275
# mse on target set =  0.31152018904685974
# Model with  logcosh as loss,  elu  as activation function,  elu  as activation function in the last layer
# mse on validation set =  0.1313631385564804
# mse on target set =  0.039775300770998
# Model with  logcosh as loss,  elu  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.167724609375
# mse on target set =  0.054210491478443146
# Model with  logcosh as loss,  selu  as activation function,  elu  as activation function in the last layer
# mse on validation set =  0.10156579315662384
# mse on target set =  0.011221565306186676
# Model with  logcosh as loss,  selu  as activation function,  selu  as activation function in the last layer
# mse on validation set =  0.1923932284116745
# mse on target set =  0.06432711333036423

# %%
acctar_loss_elu = []
acctar_loss_selu = []
for i in range(len(acctar_loss)):
    if (i%2 == 0):
        acctar_loss_elu.append(acctar_loss[i])
    else:
        acctar_loss_selu.append(acctar_loss[i])

acctar_loss_elu = np.round(acctar_loss_elu, decimals=3)
acctar_loss_selu = np.round(acctar_loss_selu, decimals=3)

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
## righe = loss, cols = attivazione
acctar_loss_elu = np.reshape(acctar_loss_elu,(4,4))
acctar_loss_selu = np.reshape(acctar_loss_selu,(4,4))

fig, (ax1,ax2) = plt.subplots(1,2, figsize=(20,10))
divider = make_axes_locatable(ax1)
cax1 = divider.append_axes('right', size='5%', pad=0.05)
divider = make_axes_locatable(ax2)
cax2 = divider.append_axes('right', size='5%', pad=0.05)

im1 = ax1.imshow(acctar_loss_elu)
ax1.set_xticks(np.arange(len(loss)))
ax1.set_yticks(np.arange(len(act)))
ax1.set_xticklabels(loss,size=18)
ax1.set_yticklabels(act,size=18)
ax1.set_xlabel("Loss function",size=18)
ax1.set_ylabel("Activation function",size=18)
ax1.set_title("Accuracy values on target set - elu in the last layer", size=18)
plt.setp(ax1.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

for i in range(len(loss)):
    for j in range(len(act)):
        text = ax1.text(j, i, acctar_loss_elu[i, j],
                       ha="center", va="center", color="w", size=20)

im2 = ax2.imshow(acctar_loss_selu)
ax2.set_xticks(np.arange(len(loss)))
ax2.set_yticks(np.arange(len(act)))
ax2.set_xticklabels(loss,size=18)
ax2.set_yticklabels(act,size=18)
ax2.set_xlabel("Loss function",size=18)
ax2.set_ylabel("Activation function",size=18)
ax2.set_title("Accuracy values on target set - selu in the last layer", size=18)
plt.setp(ax1.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

for i in range(len(loss)):
    for j in range(len(act)):
        text = ax2.text(j, i, acctar_loss_selu[i, j],
                       ha="center", va="center", color="w", size=20)
        
fig.colorbar(im1, cax=cax1, orientation='vertical')
fig.colorbar(im2, cax=cax2, orientation='vertical')

# %% [markdown]
# Models with the lowest metrics were plotted:
# - mse, tanh, selu in the last layer
# - logcosh, tanh, selu in the last layer
# - logcosh, elu, selu in the last layer
# - logcosh, elu, elu in the last layer

# %%
model_elu = []
model_selu = []
for i in range(len(model_loss)):
    if (i%2 == 0):
        model_elu.append(model_loss[i])
    else:
        model_selu.append(model_loss[i])

# plot
x_predicted = np.random.uniform(-1.5, 1.5, 200)
y_predicted1 = model_selu[0].predict(x_predicted) #mse, tanh, selu in the last layer
y_predicted2 = model_selu[3].predict(x_predicted) #logcosh, tanh, selu in the last layer
y_predicted3 = model_selu[11].predict(x_predicted) #logcosh, elu, selu in the last layer
y_predicted4 = model_elu[11].predict(x_predicted) #logcosh, elu, elu in the last layer

plt.figure(figsize=(9,6))

plt.scatter(x_predicted, y_predicted1, s=10, label = "mse, tanh, selu in the last layer")
plt.scatter(x_predicted, y_predicted2, s=10, label = "logcosh, tanh, selu in the last layer")
plt.scatter(x_predicted, y_predicted3, s=10, label = "logcosh, elu, selu in the last layer")
plt.scatter(x_predicted, y_predicted4, s=10, label = "logcosh, elu, elu in the last layer")
plt.plot(x_valid, y_target, label = "Target function", color="k")
plt.xlabel("x",size=13)
plt.ylabel("y",size=13)
plt.title("Predictions vs target function", size=13)
plt.legend(loc="upper right", fontsize=10)
plt.grid(True); plt.show()

# %% [markdown]
# ### 11.3
#
# In this part the NN was applied to a 2D function: $f(x,y) = \sin(x^2+y^2)$ in the range $x \in [-3/2,3/2]$ and $y \in [-3/2,3/2]$.
#
# At first, I tried to apply the model with the best score in 11.2: 10 layers of 25 nodes each, *mse* as loss function, *selu* as activation function in the last layer and *tanh* as activation function in the other layers. Moreover, I increased the size of training and validation sets (keeping $N_{valid} = 0.1 \times N_{train}$) and slightly reduced the noise standard deviation.

# %%
### importing libraries
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects
#from tensorflow.keras.callbacks import EarlyStopping

# %%
def func2d (x,y):
    a = x**2 + y**2
    return np.sin(a)

# %%
## training and validation sets
np.random.seed(0)
ntrain = 20000
nvalid = 2000

x_train = np.random.uniform(-1.5, 1.5, ntrain)
x_valid = np.random.uniform(-1.5, 1.5, nvalid)
x_valid.sort()
y_train = np.random.uniform(-1.5, 1.5, ntrain)
y_valid = np.random.uniform(-1.5, 1.5, nvalid)
y_valid.sort()

z_target = func2d(x_valid, y_valid) # ideal (target) function

sigma = 0.25 # noise or standard deviation
z_train = np.random.normal(func2d(x_train, y_train), sigma) # actual measures from which we want to guess regression parameters
z_valid = np.random.normal(func2d(x_valid, y_valid), sigma)

## algo input
data_train = np.zeros((ntrain,2))
data_valid = np.zeros((nvalid, 2))
for i in range(ntrain):
    data_train[i,0] = x_train[i]
    data_train[i,1] = y_train[i]
for j in range(nvalid):
    data_valid[j,0] = x_valid[j]
    data_valid[j,1] = y_valid[j]

# %%
x_valid
# Out:
# array([-1.49517472, -1.49361407, -1.49337633, ...,  1.49808321,
#         1.498509  ,  1.49956583])

# %%
y_valid
# Out:
# array([-1.49939971, -1.49753904, -1.49319875, ...,  1.49611903,
#         1.49854038,  1.49985173])

# %%
data_valid
# Out:
# array([[-1.49517472, -1.49939971],
#        [-1.49361407, -1.49753904],
#        [-1.49337633, -1.49319875],
#        ...,
#        [ 1.49808321,  1.49611903],
#        [ 1.498509  ,  1.49854038],
#        [ 1.49956583,  1.49985173]])

# %%
x_train
# Out:
# array([ 0.14644051,  0.6455681 ,  0.30829013, ..., -0.16063272,
#        -0.41962016,  0.37765994])

# %%
y_train
# Out:
# array([ 1.44281262, -0.66112998, -0.55574141, ...,  1.33874901,
#         1.41012905, -0.34831621])

# %%
data_train
# Out:
# array([[ 0.14644051,  1.44281262],
#        [ 0.6455681 , -0.66112998],
#        [ 0.30829013, -0.55574141],
#        ...,
#        [-0.16063272,  1.33874901],
#        [-0.41962016,  1.41012905],
#        [ 0.37765994, -0.34831621]])

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter


fig = plt.figure(figsize=(9,9))
ax = fig.gca(projection='3d')

# Make data.
X = x_valid
Y = y_valid
X, Y = np.meshgrid(X, Y)
R = (X**2 + Y**2)
Z = np.sin(R)

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap="Blues",
                       linewidth=0, antialiased=False)
## Add points
ax.scatter(x_train, y_train, z_train, color = "aqua", s=10, label="Training set")
ax.scatter(x_valid, y_valid, z_valid, color='green', s=30, label="Validation set")

ax.set_xlabel("x",size=13)
ax.set_ylabel("y",size=13)
ax.set_title("Training set, validation set and target function", size=13)
ax.legend(loc="upper right", fontsize=13)
ax.view_init(15, 20)
# Add a color bar which maps values to colors
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
###MODEL 1: 10 layers of 25 nodes each, 
###*mse* as loss function, tanh + selu

model1 = Sequential()
model1.add(Dense(25, input_shape=(2,), activation='tanh')) 
for i in range(8):
    model1.add(Dense(25, activation='tanh'))
model1.add(Dense(1, activation='linear'))
model1.compile(optimizer='sgd', loss='mse', metrics=['mse'])

model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 25)                75
# _________________________________________________________________
# dense_1 (Dense)              (None, 25)                650
# _________________________________________________________________
# dense_2 (Dense)              (None, 25)                650
# _________________________________________________________________
# dense_3 (Dense)              (None, 25)                650
# _________________________________________________________________
# dense_4 (Dense)              (None, 25)                650
# _________________________________________________________________
# dense_5 (Dense)              (None, 25)                650
# _________________________________________________________________
# dense_6 (Dense)              (None, 25)                650
# _________________________________________________________________
# dense_7 (Dense)              (None, 25)                650
# _________________________________________________________________
# dense_8 (Dense)              (None, 25)                650
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 26
# =================================================================
# Total params: 5,301
# Trainable params: 5,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
history1 = model1.fit(x=data_train, y=z_train, 
          batch_size=128, epochs=200,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(data_valid, z_valid))
# Out:
# Epoch 1/200
# 157/157 [==============================] - 1s 3ms/step - loss: 0.2247 - mse: 0.2247 - val_loss: 0.4518 - val_mse: 0.4518
# Epoch 2/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2133 - mse: 0.2133 - val_loss: 0.4198 - val_mse: 0.4198
# Epoch 3/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2124 - mse: 0.2124 - val_loss: 0.4507 - val_mse: 0.4507
# Epoch 4/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2116 - mse: 0.2116 - val_loss: 0.4512 - val_mse: 0.4512
# Epoch 5/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2109 - mse: 0.2109 - val_loss: 0.4391 - val_mse: 0.4391
# Epoch 6/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2102 - mse: 0.2102 - val_loss: 0.4441 - val_mse: 0.4441
# Epoch 7/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2095 - mse: 0.2095 - val_loss: 0.4367 - val_mse: 0.4367
# Epoch 8/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2085 - mse: 0.2085 - val_loss: 0.4530 - val_mse: 0.4530
# Epoch 9/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2076 - mse: 0.2076 - val_loss: 0.4350 - val_mse: 0.4350
# Epoch 10/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2059 - mse: 0.2059 - val_loss: 0.4219 - val_mse: 0.4219
# Epoch 11/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2037 - mse: 0.2037 - val_loss: 0.4213 - val_mse: 0.4213
# Epoch 12/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1998 - mse: 0.1998 - val_loss: 0.4193 - val_mse: 0.4193
# Epoch 13/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1938 - mse: 0.1938 - val_loss: 0.3972 - val_mse: 0.3972
# Epoch 14/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1859 - mse: 0.1859 - val_loss: 0.3896 - val_mse: 0.3896
# Epoch 15/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1759 - mse: 0.1759 - val_loss: 0.3774 - val_mse: 0.3774
# Epoch 16/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1652 - mse: 0.1652 - val_loss: 0.3818 - val_mse: 0.3818
# Epoch 17/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1557 - mse: 0.1557 - val_loss: 0.3159 - val_mse: 0.3159
# Epoch 18/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1480 - mse: 0.1480 - val_loss: 0.3281 - val_mse: 0.3281
# Epoch 19/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1419 - mse: 0.1419 - val_loss: 0.3328 - val_mse: 0.3328
# Epoch 20/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1374 - mse: 0.1374 - val_loss: 0.2945 - val_mse: 0.2945
# Epoch 21/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1346 - mse: 0.1346 - val_loss: 0.2791 - val_mse: 0.2791
# Epoch 22/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1325 - mse: 0.1325 - val_loss: 0.2445 - val_mse: 0.2445
# Epoch 23/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1322 - mse: 0.1322 - val_loss: 0.2430 - val_mse: 0.2430
# Epoch 24/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1285 - mse: 0.1285 - val_loss: 0.2456 - val_mse: 0.2456
# Epoch 25/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1263 - mse: 0.1263 - val_loss: 0.2268 - val_mse: 0.2268
# Epoch 26/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1260 - mse: 0.1260 - val_loss: 0.2162 - val_mse: 0.2162
# Epoch 27/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1266 - mse: 0.1266 - val_loss: 0.2506 - val_mse: 0.2506
# Epoch 28/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1215 - mse: 0.1215 - val_loss: 0.2457 - val_mse: 0.2457
# Epoch 29/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1243 - mse: 0.1243 - val_loss: 0.2039 - val_mse: 0.2039
# Epoch 30/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1223 - mse: 0.1223 - val_loss: 0.1965 - val_mse: 0.1965
# Epoch 31/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1163 - mse: 0.1163 - val_loss: 0.1926 - val_mse: 0.1926
# Epoch 32/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1174 - mse: 0.1174 - val_loss: 0.1754 - val_mse: 0.1754
# Epoch 33/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1169 - mse: 0.1169 - val_loss: 0.1853 - val_mse: 0.1853
# Epoch 34/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1110 - mse: 0.1110 - val_loss: 0.1788 - val_mse: 0.1788
# Epoch 35/200
# 157/157 [==============================] - 0s 3ms/step - loss: 0.1113 - mse: 0.1113 - val_loss: 0.1610 - val_mse: 0.1610
# Epoch 36/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1066 - mse: 0.1066 - val_loss: 0.1722 - val_mse: 0.1722
# Epoch 37/200
# 157/157 [==============================] - 0s 3ms/step - loss: 0.1051 - mse: 0.1051 - val_loss: 0.1566 - val_mse: 0.1566
# Epoch 38/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1001 - mse: 0.1001 - val_loss: 0.2066 - val_mse: 0.2066
# Epoch 39/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0993 - mse: 0.0993 - val_loss: 0.1213 - val_mse: 0.1213
# Epoch 40/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0943 - mse: 0.0943 - val_loss: 0.1217 - val_mse: 0.1217
# Epoch 41/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0913 - mse: 0.0913 - val_loss: 0.1013 - val_mse: 0.1013
# Epoch 42/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0863 - mse: 0.0863 - val_loss: 0.0941 - val_mse: 0.0941
# Epoch 43/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0808 - mse: 0.0808 - val_loss: 0.0870 - val_mse: 0.0870
# Epoch 44/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0783 - mse: 0.0783 - val_loss: 0.1058 - val_mse: 0.1058
# Epoch 45/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0747 - mse: 0.0747 - val_loss: 0.0865 - val_mse: 0.0865
# Epoch 46/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0727 - mse: 0.0727 - val_loss: 0.0904 - val_mse: 0.0904
# Epoch 47/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0711 - mse: 0.0711 - val_loss: 0.0736 - val_mse: 0.0736
# Epoch 48/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0699 - mse: 0.0699 - val_loss: 0.0996 - val_mse: 0.0996
# Epoch 49/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0689 - mse: 0.0689 - val_loss: 0.0676 - val_mse: 0.0676
# Epoch 50/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0690 - mse: 0.0690 - val_loss: 0.0694 - val_mse: 0.0694
# Epoch 51/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0677 - mse: 0.0677 - val_loss: 0.0796 - val_mse: 0.0796
# Epoch 52/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0673 - mse: 0.0673 - val_loss: 0.1136 - val_mse: 0.1136
# Epoch 53/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0677 - mse: 0.0677 - val_loss: 0.0676 - val_mse: 0.0676
# Epoch 54/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0676 - mse: 0.0676 - val_loss: 0.0668 - val_mse: 0.0668
# Epoch 55/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0671 - mse: 0.0671 - val_loss: 0.0706 - val_mse: 0.0706
# Epoch 56/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0664 - mse: 0.0664 - val_loss: 0.0678 - val_mse: 0.0678
# Epoch 57/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0668 - mse: 0.0668 - val_loss: 0.0920 - val_mse: 0.0920
# Epoch 58/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0663 - mse: 0.0663 - val_loss: 0.1112 - val_mse: 0.1112
# Epoch 59/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0662 - mse: 0.0662 - val_loss: 0.0687 - val_mse: 0.0687
# Epoch 60/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0661 - mse: 0.0661 - val_loss: 0.0821 - val_mse: 0.0821
# Epoch 61/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0663 - mse: 0.0663 - val_loss: 0.0718 - val_mse: 0.0718
# Epoch 62/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0662 - mse: 0.0662 - val_loss: 0.0749 - val_mse: 0.0749
# Epoch 63/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0660 - mse: 0.0660 - val_loss: 0.0752 - val_mse: 0.0752
# Epoch 64/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0659 - mse: 0.0659 - val_loss: 0.0699 - val_mse: 0.0699
# Epoch 65/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0659 - mse: 0.0659 - val_loss: 0.0910 - val_mse: 0.0910
# Epoch 66/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0653 - mse: 0.0653 - val_loss: 0.0719 - val_mse: 0.0719
# Epoch 67/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0656 - mse: 0.0656 - val_loss: 0.0721 - val_mse: 0.0721
# Epoch 68/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0656 - mse: 0.0656 - val_loss: 0.0686 - val_mse: 0.0686
# Epoch 69/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0654 - mse: 0.0654 - val_loss: 0.0679 - val_mse: 0.0679
# Epoch 70/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0649 - mse: 0.0649 - val_loss: 0.0772 - val_mse: 0.0772
# Epoch 71/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0653 - mse: 0.0653 - val_loss: 0.0743 - val_mse: 0.0743
# Epoch 72/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0652 - mse: 0.0652 - val_loss: 0.0647 - val_mse: 0.0647
# Epoch 73/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0650 - mse: 0.0650 - val_loss: 0.0862 - val_mse: 0.0862
# Epoch 74/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0650 - mse: 0.0650 - val_loss: 0.0771 - val_mse: 0.0771
# Epoch 75/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0648 - mse: 0.0648 - val_loss: 0.0731 - val_mse: 0.0731
# Epoch 76/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0650 - mse: 0.0650 - val_loss: 0.0703 - val_mse: 0.0703
# Epoch 77/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0652 - mse: 0.0652 - val_loss: 0.0707 - val_mse: 0.0707
# Epoch 78/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0653 - mse: 0.0653 - val_loss: 0.0674 - val_mse: 0.0674
# Epoch 79/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0646 - mse: 0.0646 - val_loss: 0.0668 - val_mse: 0.0668
# Epoch 80/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0647 - mse: 0.0647 - val_loss: 0.0679 - val_mse: 0.0679
# Epoch 81/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0648 - mse: 0.0648 - val_loss: 0.0672 - val_mse: 0.0672
# Epoch 82/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0650 - mse: 0.0650 - val_loss: 0.0633 - val_mse: 0.0633
# Epoch 83/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0649 - mse: 0.0649 - val_loss: 0.0677 - val_mse: 0.0677
# Epoch 84/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0643 - mse: 0.0643 - val_loss: 0.0663 - val_mse: 0.0663
# Epoch 85/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0647 - mse: 0.0647 - val_loss: 0.0676 - val_mse: 0.0676
# Epoch 86/200
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0643 - mse: 0.0643 - val_loss: 0.0686 - val_mse: 0.0686
# Epoch 87/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0643 - mse: 0.0643 - val_loss: 0.0656 - val_mse: 0.0656
# Epoch 88/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0641 - mse: 0.0641 - val_loss: 0.0634 - val_mse: 0.0634
# Epoch 89/200
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0645 - mse: 0.0645 - val_loss: 0.0631 - val_mse: 0.0631
# Epoch 90/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0644 - mse: 0.0644 - val_loss: 0.0915 - val_mse: 0.0915
# Epoch 91/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0647 - mse: 0.0647 - val_loss: 0.0708 - val_mse: 0.0708
# Epoch 92/200
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0643 - mse: 0.0643 - val_loss: 0.0767 - val_mse: 0.0767
# Epoch 93/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0645 - mse: 0.0645 - val_loss: 0.0639 - val_mse: 0.0639
# Epoch 94/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0641 - mse: 0.0641 - val_loss: 0.0652 - val_mse: 0.0652
# Epoch 95/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0644 - mse: 0.0644 - val_loss: 0.0654 - val_mse: 0.0654
# Epoch 96/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0642 - mse: 0.0642 - val_loss: 0.0675 - val_mse: 0.0675
# Epoch 97/200
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0644 - mse: 0.0644 - val_loss: 0.0695 - val_mse: 0.0695
# Epoch 98/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0639 - mse: 0.0639 - val_loss: 0.0642 - val_mse: 0.0642
# Epoch 99/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0641 - mse: 0.0641 - val_loss: 0.0642 - val_mse: 0.0642
# Epoch 100/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0641 - mse: 0.0641 - val_loss: 0.0712 - val_mse: 0.0712
# Epoch 101/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0642 - mse: 0.0642 - val_loss: 0.0637 - val_mse: 0.0637
# Epoch 102/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0643 - mse: 0.0643 - val_loss: 0.0727 - val_mse: 0.0727
# Epoch 103/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0640 - mse: 0.0640 - val_loss: 0.0640 - val_mse: 0.0640
# Epoch 104/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0639 - mse: 0.0639 - val_loss: 0.0740 - val_mse: 0.0740
# Epoch 105/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0642 - mse: 0.0642 - val_loss: 0.0673 - val_mse: 0.0673
# Epoch 106/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0639 - mse: 0.0639 - val_loss: 0.0648 - val_mse: 0.0648
# Epoch 107/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0639 - mse: 0.0639 - val_loss: 0.0665 - val_mse: 0.0665
# Epoch 108/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0640 - mse: 0.0640 - val_loss: 0.0719 - val_mse: 0.0719
# Epoch 109/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0640 - mse: 0.0640 - val_loss: 0.0714 - val_mse: 0.0714
# Epoch 110/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0640 - mse: 0.0640 - val_loss: 0.0687 - val_mse: 0.0687
# Epoch 111/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0638 - mse: 0.0638 - val_loss: 0.0641 - val_mse: 0.0641
# Epoch 112/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0639 - mse: 0.0639 - val_loss: 0.0767 - val_mse: 0.0767
# Epoch 113/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0638 - mse: 0.0638 - val_loss: 0.0749 - val_mse: 0.0749
# Epoch 114/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0639 - mse: 0.0639 - val_loss: 0.0718 - val_mse: 0.0718
# Epoch 115/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0638 - mse: 0.0638 - val_loss: 0.0657 - val_mse: 0.0657
# Epoch 116/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0640 - mse: 0.0640 - val_loss: 0.0668 - val_mse: 0.0668
# Epoch 117/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0637 - mse: 0.0637 - val_loss: 0.0640 - val_mse: 0.0640
# Epoch 118/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0639 - mse: 0.0639 - val_loss: 0.0715 - val_mse: 0.0715
# Epoch 119/200
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0638 - mse: 0.0638 - val_loss: 0.0635 - val_mse: 0.0635
# Epoch 120/200
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0638 - mse: 0.0638 - val_loss: 0.0786 - val_mse: 0.0786
# Epoch 121/200
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0639 - mse: 0.0639 - val_loss: 0.0633 - val_mse: 0.0633
# Epoch 122/200
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0639 - mse: 0.0639 - val_loss: 0.0758 - val_mse: 0.0758
# Epoch 123/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0638 - mse: 0.0638 - val_loss: 0.0685 - val_mse: 0.0685
# Epoch 124/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0637 - mse: 0.0637 - val_loss: 0.0637 - val_mse: 0.0637
# Epoch 125/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0636 - mse: 0.0636 - val_loss: 0.0788 - val_mse: 0.0788
# Epoch 126/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0636 - mse: 0.0636 - val_loss: 0.0671 - val_mse: 0.0671
# Epoch 127/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0638 - mse: 0.0638 - val_loss: 0.0659 - val_mse: 0.0659
# Epoch 128/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0639 - mse: 0.0639 - val_loss: 0.0648 - val_mse: 0.0648
# Epoch 129/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0636 - mse: 0.0636 - val_loss: 0.0966 - val_mse: 0.0966
# Epoch 130/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0637 - mse: 0.0637 - val_loss: 0.0648 - val_mse: 0.0648
# Epoch 131/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0636 - mse: 0.0636 - val_loss: 0.0798 - val_mse: 0.0798
# Epoch 132/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0639 - mse: 0.0639 - val_loss: 0.0761 - val_mse: 0.0761
# Epoch 133/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0636 - mse: 0.0636 - val_loss: 0.0641 - val_mse: 0.0641
# Epoch 134/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0637 - mse: 0.0637 - val_loss: 0.0649 - val_mse: 0.0649
# Epoch 135/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0638 - mse: 0.0638 - val_loss: 0.0643 - val_mse: 0.0643
# Epoch 136/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0636 - mse: 0.0636 - val_loss: 0.0784 - val_mse: 0.0784
# Epoch 137/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0636 - mse: 0.0636 - val_loss: 0.0644 - val_mse: 0.0644
# Epoch 138/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0637 - mse: 0.0637 - val_loss: 0.0665 - val_mse: 0.0665
# Epoch 139/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0636 - mse: 0.0636 - val_loss: 0.0938 - val_mse: 0.0938
# Epoch 140/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0638 - mse: 0.0638 - val_loss: 0.0808 - val_mse: 0.0808
# Epoch 141/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0636 - mse: 0.0636 - val_loss: 0.0669 - val_mse: 0.0669
# Epoch 142/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0634 - mse: 0.0634 - val_loss: 0.0681 - val_mse: 0.0681
# Epoch 143/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0636 - mse: 0.0636 - val_loss: 0.0636 - val_mse: 0.0636
# Epoch 144/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0637 - mse: 0.0637 - val_loss: 0.1252 - val_mse: 0.1252
# Epoch 145/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0639 - mse: 0.0639 - val_loss: 0.0640 - val_mse: 0.0640
# Epoch 146/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0637 - mse: 0.0637 - val_loss: 0.0641 - val_mse: 0.0641
# Epoch 147/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0636 - mse: 0.0636 - val_loss: 0.0690 - val_mse: 0.0690
# Epoch 148/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0635 - mse: 0.0635 - val_loss: 0.0639 - val_mse: 0.0639
# Epoch 149/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0634 - mse: 0.0634 - val_loss: 0.0650 - val_mse: 0.0650
# Epoch 150/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0635 - mse: 0.0635 - val_loss: 0.0645 - val_mse: 0.0645
# Epoch 151/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0636 - mse: 0.0636 - val_loss: 0.0641 - val_mse: 0.0641
# Epoch 152/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0636 - mse: 0.0636 - val_loss: 0.0650 - val_mse: 0.0650
# Epoch 153/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0634 - mse: 0.0634 - val_loss: 0.0633 - val_mse: 0.0633
# Epoch 154/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0634 - mse: 0.0634 - val_loss: 0.0727 - val_mse: 0.0727
# Epoch 155/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0634 - mse: 0.0634 - val_loss: 0.0680 - val_mse: 0.0680
# Epoch 156/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0636 - mse: 0.0636 - val_loss: 0.0681 - val_mse: 0.0681
# Epoch 157/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0637 - mse: 0.0637 - val_loss: 0.0679 - val_mse: 0.0679
# Epoch 158/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0637 - mse: 0.0637 - val_loss: 0.0635 - val_mse: 0.0635
# Epoch 159/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0636 - mse: 0.0636 - val_loss: 0.0673 - val_mse: 0.0673
# Epoch 160/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0635 - mse: 0.0635 - val_loss: 0.0666 - val_mse: 0.0666
# Epoch 161/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0635 - mse: 0.0635 - val_loss: 0.0653 - val_mse: 0.0653
# Epoch 162/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0634 - mse: 0.0634 - val_loss: 0.0701 - val_mse: 0.0701
# Epoch 163/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0635 - mse: 0.0635 - val_loss: 0.0640 - val_mse: 0.0640
# Epoch 164/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0633 - mse: 0.0633 - val_loss: 0.0691 - val_mse: 0.0691
# Epoch 165/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0636 - mse: 0.0636 - val_loss: 0.0675 - val_mse: 0.0675
# Epoch 166/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0635 - mse: 0.0635 - val_loss: 0.0713 - val_mse: 0.0713
# Epoch 167/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0634 - mse: 0.0634 - val_loss: 0.0651 - val_mse: 0.0651
# Epoch 168/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0634 - mse: 0.0634 - val_loss: 0.0657 - val_mse: 0.0657
# Epoch 169/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0635 - mse: 0.0635 - val_loss: 0.0683 - val_mse: 0.0683
# Epoch 170/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0635 - mse: 0.0635 - val_loss: 0.0666 - val_mse: 0.0666
# Epoch 171/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0634 - mse: 0.0634 - val_loss: 0.0703 - val_mse: 0.0703
# Epoch 172/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0634 - mse: 0.0634 - val_loss: 0.0758 - val_mse: 0.0758
# Epoch 173/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0634 - mse: 0.0634 - val_loss: 0.0789 - val_mse: 0.0789
# Epoch 174/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0635 - mse: 0.0635 - val_loss: 0.0643 - val_mse: 0.0643
# Epoch 175/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0636 - mse: 0.0636 - val_loss: 0.0678 - val_mse: 0.0678
# Epoch 176/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0636 - mse: 0.0636 - val_loss: 0.0666 - val_mse: 0.0666
# Epoch 177/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0635 - mse: 0.0635 - val_loss: 0.0651 - val_mse: 0.0651
# Epoch 178/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0634 - mse: 0.0634 - val_loss: 0.0651 - val_mse: 0.0651
# Epoch 179/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0635 - mse: 0.0635 - val_loss: 0.0659 - val_mse: 0.0659
# Epoch 180/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0635 - mse: 0.0635 - val_loss: 0.0712 - val_mse: 0.0712
# Epoch 181/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0635 - mse: 0.0635 - val_loss: 0.0646 - val_mse: 0.0646
# Epoch 182/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0634 - mse: 0.0634 - val_loss: 0.0731 - val_mse: 0.0731
# Epoch 183/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0635 - mse: 0.0635 - val_loss: 0.0685 - val_mse: 0.0685
# Epoch 184/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0635 - mse: 0.0635 - val_loss: 0.0761 - val_mse: 0.0761
# Epoch 185/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0637 - mse: 0.0637 - val_loss: 0.0661 - val_mse: 0.0661
# Epoch 186/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0636 - mse: 0.0636 - val_loss: 0.0642 - val_mse: 0.0642
# Epoch 187/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0633 - mse: 0.0633 - val_loss: 0.0656 - val_mse: 0.0656
# Epoch 188/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0634 - mse: 0.0634 - val_loss: 0.0700 - val_mse: 0.0700
# Epoch 189/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0633 - mse: 0.0633 - val_loss: 0.0670 - val_mse: 0.0670
# Epoch 190/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0633 - mse: 0.0633 - val_loss: 0.0635 - val_mse: 0.0635
# Epoch 191/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0633 - mse: 0.0633 - val_loss: 0.0652 - val_mse: 0.0652
# Epoch 192/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0633 - mse: 0.0633 - val_loss: 0.0632 - val_mse: 0.0632
# Epoch 193/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0633 - mse: 0.0633 - val_loss: 0.0644 - val_mse: 0.0644
# Epoch 194/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0633 - mse: 0.0633 - val_loss: 0.0639 - val_mse: 0.0639
# Epoch 195/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0634 - mse: 0.0634 - val_loss: 0.0689 - val_mse: 0.0689
# Epoch 196/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0634 - mse: 0.0634 - val_loss: 0.0731 - val_mse: 0.0731
# Epoch 197/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0635 - mse: 0.0635 - val_loss: 0.0674 - val_mse: 0.0674
# Epoch 198/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0633 - mse: 0.0633 - val_loss: 0.0704 - val_mse: 0.0704
# Epoch 199/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0634 - mse: 0.0634 - val_loss: 0.0654 - val_mse: 0.0654
# Epoch 200/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0635 - mse: 0.0635 - val_loss: 0.0682 - val_mse: 0.0682

# %%
# evaluate model
score = model1.evaluate(data_valid, z_valid, batch_size=32, verbose=0)
print("mse on validation set = ", score[1])
score = model1.evaluate(data_valid, z_target, batch_size=32, verbose=0)
print("mse on target set = ", score[1])
# Out:
# mse on validation set =  0.06819473206996918
# mse on target set =  0.006403944455087185

# %%
## plot loss function during training
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.grid(True)
plt.show()

# %%
x_predicted = np.random.uniform(-1.5, 1.5, nvalid)
y_predicted = np.random.uniform(-1.5, 1.5, nvalid)
data_predicted = np.zeros((nvalid,2))
for k in range(nvalid):
    data_predicted[k,0] = x_predicted[k]
    data_predicted[k,1] = y_predicted[k]

z_predicted = model1.predict(data_predicted)

# %%
x_predicted
# Out:
# array([ 0.52100081,  1.01810306,  1.00805959, ..., -0.23442787,
#        -0.95129006,  0.0527114 ])

# %%
y_predicted
# Out:
# array([-0.44523824,  1.02300069,  1.44280087, ...,  0.9741632 ,
#        -0.3514081 ,  1.10041129])

# %%
data_predicted
# Out:
# array([[ 0.52100081, -0.44523824],
#        [ 1.01810306,  1.02300069],
#        [ 1.00805959,  1.44280087],
#        ...,
#        [-0.23442787,  0.9741632 ],
#        [-0.95129006, -0.3514081 ],
#        [ 0.0527114 ,  1.10041129]])

# %%
np.shape(z_predicted)
# Out:
# (2000, 1)

# %%
fig = plt.figure(figsize=(9,9))
ax = fig.gca(projection='3d')

# Make data
X = x_valid
Y = y_valid
X, Y = np.meshgrid(X, Y)
R = (X**2 + Y**2)
Z = np.sin(R)

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap="Blues",
                       linewidth=0, antialiased=False)
## Add points
ax.scatter(x_predicted, y_predicted, z_predicted , color="aqua", label = "Predicted")

ax.set_xlabel("x",size=13)
ax.set_ylabel("y",size=13)
ax.set_title("Predictions vs target function", size=13)
ax.legend(loc="upper right", fontsize=13)
ax.view_init(15, 20)
# Add a color bar which maps values to colors
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
## 4 layer, 25 nodes, mse, tanh+elu
model = Sequential()
model.add(Dense(10, input_shape=(2,), activation='tanh'))
model.add(Dense(20, activation='tanh'))
model.add(Dense(20, activation='tanh'))
model.add(Dense(1, activation='linear'))
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 10)                30
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                220
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 691
# Trainable params: 691
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x=data_train, y=z_train, 
          batch_size=100, epochs=110,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(data_valid, z_valid))
# Out:
# Epoch 1/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2239 - mse: 0.2239 - val_loss: 0.4398 - val_mse: 0.4398
# Epoch 2/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2142 - mse: 0.2142 - val_loss: 0.4443 - val_mse: 0.4443
# Epoch 3/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2135 - mse: 0.2135 - val_loss: 0.4550 - val_mse: 0.4550
# Epoch 4/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2129 - mse: 0.2129 - val_loss: 0.4430 - val_mse: 0.4430
# Epoch 5/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2125 - mse: 0.2125 - val_loss: 0.4445 - val_mse: 0.4445
# Epoch 6/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2122 - mse: 0.2122 - val_loss: 0.4451 - val_mse: 0.4451
# Epoch 7/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2118 - mse: 0.2118 - val_loss: 0.4416 - val_mse: 0.4416
# Epoch 8/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2114 - mse: 0.2114 - val_loss: 0.4491 - val_mse: 0.4491
# Epoch 9/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2112 - mse: 0.2112 - val_loss: 0.4466 - val_mse: 0.4466
# Epoch 10/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2110 - mse: 0.2110 - val_loss: 0.4451 - val_mse: 0.4451
# Epoch 11/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2107 - mse: 0.2107 - val_loss: 0.4524 - val_mse: 0.4524
# Epoch 12/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2104 - mse: 0.2104 - val_loss: 0.4388 - val_mse: 0.4388
# Epoch 13/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2101 - mse: 0.2101 - val_loss: 0.4380 - val_mse: 0.4380
# Epoch 14/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2098 - mse: 0.2098 - val_loss: 0.4447 - val_mse: 0.4447
# Epoch 15/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2096 - mse: 0.2096 - val_loss: 0.4460 - val_mse: 0.4460
# Epoch 16/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2091 - mse: 0.2091 - val_loss: 0.4360 - val_mse: 0.4360
# Epoch 17/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2087 - mse: 0.2087 - val_loss: 0.4375 - val_mse: 0.4375
# Epoch 18/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2082 - mse: 0.2082 - val_loss: 0.4435 - val_mse: 0.4435
# Epoch 19/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2074 - mse: 0.2074 - val_loss: 0.4374 - val_mse: 0.4374
# Epoch 20/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2069 - mse: 0.2069 - val_loss: 0.4416 - val_mse: 0.4416
# Epoch 21/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2061 - mse: 0.2061 - val_loss: 0.4486 - val_mse: 0.4486
# Epoch 22/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2052 - mse: 0.2052 - val_loss: 0.4374 - val_mse: 0.4374
# Epoch 23/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2038 - mse: 0.2038 - val_loss: 0.4422 - val_mse: 0.4422
# Epoch 24/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2026 - mse: 0.2026 - val_loss: 0.4423 - val_mse: 0.4423
# Epoch 25/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2005 - mse: 0.2005 - val_loss: 0.4355 - val_mse: 0.4355
# Epoch 26/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1983 - mse: 0.1983 - val_loss: 0.4289 - val_mse: 0.4289
# Epoch 27/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1957 - mse: 0.1957 - val_loss: 0.4303 - val_mse: 0.4303
# Epoch 28/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1924 - mse: 0.1924 - val_loss: 0.4207 - val_mse: 0.4207
# Epoch 29/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1888 - mse: 0.1888 - val_loss: 0.4097 - val_mse: 0.4097
# Epoch 30/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1846 - mse: 0.1846 - val_loss: 0.3949 - val_mse: 0.3949
# Epoch 31/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1797 - mse: 0.1797 - val_loss: 0.3650 - val_mse: 0.3650
# Epoch 32/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1748 - mse: 0.1748 - val_loss: 0.3572 - val_mse: 0.3572
# Epoch 33/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1695 - mse: 0.1695 - val_loss: 0.3516 - val_mse: 0.3516
# Epoch 34/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1645 - mse: 0.1645 - val_loss: 0.3442 - val_mse: 0.3442
# Epoch 35/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1592 - mse: 0.1592 - val_loss: 0.3123 - val_mse: 0.3123
# Epoch 36/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1546 - mse: 0.1546 - val_loss: 0.3086 - val_mse: 0.3086
# Epoch 37/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1499 - mse: 0.1499 - val_loss: 0.2917 - val_mse: 0.2917
# Epoch 38/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1460 - mse: 0.1460 - val_loss: 0.2822 - val_mse: 0.2822
# Epoch 39/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1427 - mse: 0.1427 - val_loss: 0.2758 - val_mse: 0.2758
# Epoch 40/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1398 - mse: 0.1398 - val_loss: 0.2679 - val_mse: 0.2679
# Epoch 41/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1373 - mse: 0.1373 - val_loss: 0.2556 - val_mse: 0.2556
# Epoch 42/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1353 - mse: 0.1353 - val_loss: 0.2626 - val_mse: 0.2626
# Epoch 43/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1336 - mse: 0.1336 - val_loss: 0.2496 - val_mse: 0.2496
# Epoch 44/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1323 - mse: 0.1323 - val_loss: 0.2400 - val_mse: 0.2400
# Epoch 45/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1311 - mse: 0.1311 - val_loss: 0.2373 - val_mse: 0.2373
# Epoch 46/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1299 - mse: 0.1299 - val_loss: 0.2368 - val_mse: 0.2368
# Epoch 47/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1288 - mse: 0.1288 - val_loss: 0.2322 - val_mse: 0.2322
# Epoch 48/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1278 - mse: 0.1278 - val_loss: 0.2247 - val_mse: 0.2247
# Epoch 49/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1268 - mse: 0.1268 - val_loss: 0.2278 - val_mse: 0.2278
# Epoch 50/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1257 - mse: 0.1257 - val_loss: 0.2225 - val_mse: 0.2225
# Epoch 51/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1249 - mse: 0.1249 - val_loss: 0.2256 - val_mse: 0.2256
# Epoch 52/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1238 - mse: 0.1238 - val_loss: 0.2166 - val_mse: 0.2166
# Epoch 53/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1230 - mse: 0.1230 - val_loss: 0.2128 - val_mse: 0.2128
# Epoch 54/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1218 - mse: 0.1218 - val_loss: 0.2184 - val_mse: 0.2184
# Epoch 55/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1210 - mse: 0.1210 - val_loss: 0.2115 - val_mse: 0.2115
# Epoch 56/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1200 - mse: 0.1200 - val_loss: 0.2045 - val_mse: 0.2045
# Epoch 57/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1189 - mse: 0.1189 - val_loss: 0.2006 - val_mse: 0.2006
# Epoch 58/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1178 - mse: 0.1178 - val_loss: 0.2029 - val_mse: 0.2029
# Epoch 59/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1170 - mse: 0.1170 - val_loss: 0.1967 - val_mse: 0.1967
# Epoch 60/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1159 - mse: 0.1159 - val_loss: 0.1932 - val_mse: 0.1932
# Epoch 61/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1149 - mse: 0.1149 - val_loss: 0.1890 - val_mse: 0.1890
# Epoch 62/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1136 - mse: 0.1136 - val_loss: 0.1901 - val_mse: 0.1901
# Epoch 63/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1125 - mse: 0.1125 - val_loss: 0.1867 - val_mse: 0.1867
# Epoch 64/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1115 - mse: 0.1115 - val_loss: 0.1829 - val_mse: 0.1829
# Epoch 65/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1104 - mse: 0.1104 - val_loss: 0.1831 - val_mse: 0.1831
# Epoch 66/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1094 - mse: 0.1094 - val_loss: 0.1775 - val_mse: 0.1775
# Epoch 67/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1083 - mse: 0.1083 - val_loss: 0.1798 - val_mse: 0.1798
# Epoch 68/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1070 - mse: 0.1070 - val_loss: 0.1752 - val_mse: 0.1752
# Epoch 69/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1059 - mse: 0.1059 - val_loss: 0.1673 - val_mse: 0.1673
# Epoch 70/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1045 - mse: 0.1045 - val_loss: 0.1674 - val_mse: 0.1674
# Epoch 71/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1035 - mse: 0.1035 - val_loss: 0.1663 - val_mse: 0.1663
# Epoch 72/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1024 - mse: 0.1024 - val_loss: 0.1594 - val_mse: 0.1594
# Epoch 73/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1011 - mse: 0.1011 - val_loss: 0.1540 - val_mse: 0.1540
# Epoch 74/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1001 - mse: 0.1001 - val_loss: 0.1517 - val_mse: 0.1517
# Epoch 75/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0989 - mse: 0.0989 - val_loss: 0.1509 - val_mse: 0.1509
# Epoch 76/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0979 - mse: 0.0979 - val_loss: 0.1472 - val_mse: 0.1472
# Epoch 77/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0969 - mse: 0.0969 - val_loss: 0.1439 - val_mse: 0.1439
# Epoch 78/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0961 - mse: 0.0961 - val_loss: 0.1427 - val_mse: 0.1427
# Epoch 79/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0949 - mse: 0.0949 - val_loss: 0.1398 - val_mse: 0.1398
# Epoch 80/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0939 - mse: 0.0939 - val_loss: 0.1350 - val_mse: 0.1350
# Epoch 81/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0929 - mse: 0.0929 - val_loss: 0.1327 - val_mse: 0.1327
# Epoch 82/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0918 - mse: 0.0918 - val_loss: 0.1329 - val_mse: 0.1329
# Epoch 83/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0911 - mse: 0.0911 - val_loss: 0.1286 - val_mse: 0.1286
# Epoch 84/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0904 - mse: 0.0904 - val_loss: 0.1264 - val_mse: 0.1264
# Epoch 85/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0893 - mse: 0.0893 - val_loss: 0.1239 - val_mse: 0.1239
# Epoch 86/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0884 - mse: 0.0884 - val_loss: 0.1202 - val_mse: 0.1202
# Epoch 87/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0877 - mse: 0.0877 - val_loss: 0.1204 - val_mse: 0.1204
# Epoch 88/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0868 - mse: 0.0868 - val_loss: 0.1168 - val_mse: 0.1168
# Epoch 89/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0860 - mse: 0.0860 - val_loss: 0.1124 - val_mse: 0.1124
# Epoch 90/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0852 - mse: 0.0852 - val_loss: 0.1121 - val_mse: 0.1121
# Epoch 91/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0844 - mse: 0.0844 - val_loss: 0.1099 - val_mse: 0.1099
# Epoch 92/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0838 - mse: 0.0838 - val_loss: 0.1099 - val_mse: 0.1099
# Epoch 93/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0830 - mse: 0.0830 - val_loss: 0.1095 - val_mse: 0.1095
# Epoch 94/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0826 - mse: 0.0826 - val_loss: 0.1052 - val_mse: 0.1052
# Epoch 95/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0820 - mse: 0.0820 - val_loss: 0.1006 - val_mse: 0.1006
# Epoch 96/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0811 - mse: 0.0811 - val_loss: 0.0992 - val_mse: 0.0992
# Epoch 97/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0805 - mse: 0.0805 - val_loss: 0.0965 - val_mse: 0.0965
# Epoch 98/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0801 - mse: 0.0801 - val_loss: 0.0983 - val_mse: 0.0983
# Epoch 99/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0794 - mse: 0.0794 - val_loss: 0.0969 - val_mse: 0.0969
# Epoch 100/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0787 - mse: 0.0787 - val_loss: 0.0922 - val_mse: 0.0922
# Epoch 101/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0781 - mse: 0.0781 - val_loss: 0.0942 - val_mse: 0.0942
# Epoch 102/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0774 - mse: 0.0774 - val_loss: 0.0899 - val_mse: 0.0899
# Epoch 103/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0771 - mse: 0.0771 - val_loss: 0.0921 - val_mse: 0.0921
# Epoch 104/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0768 - mse: 0.0768 - val_loss: 0.0873 - val_mse: 0.0873
# Epoch 105/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0761 - mse: 0.0761 - val_loss: 0.0874 - val_mse: 0.0874
# Epoch 106/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0755 - mse: 0.0755 - val_loss: 0.0852 - val_mse: 0.0852
# Epoch 107/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0752 - mse: 0.0752 - val_loss: 0.0842 - val_mse: 0.0842
# Epoch 108/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0745 - mse: 0.0745 - val_loss: 0.0828 - val_mse: 0.0828
# Epoch 109/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0744 - mse: 0.0744 - val_loss: 0.0839 - val_mse: 0.0839
# Epoch 110/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0738 - mse: 0.0738 - val_loss: 0.0846 - val_mse: 0.0846

# %%
# evaluate model
score = model.evaluate(data_valid, z_valid, batch_size=32, verbose=0)
print("mse on validation set = ", score[1])
score = model.evaluate(data_valid, z_target, batch_size=32, verbose=0)
print("mse on target set = ", score[1])
# Out:
# mse on validation set =  0.08459293097257614
# mse on target set =  0.0229896642267704

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
plt.plot(history.history['mse'])
plt.plot(history.history['val_mse'])
plt.title('Model accuracy')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
x_predicted = np.random.uniform(-1.5, 1.5, nvalid)
y_predicted = np.random.uniform(-1.5, 1.5, nvalid)
data_predicted = np.zeros((nvalid,2))
for k in range(nvalid):
    data_predicted[k,0] = x_predicted[k]
    data_predicted[k,1] = y_predicted[k]

z_predicted = model.predict(data_predicted)

# %%
np.array(z_predicted)
# Out:
# array([[0.573206  ],
#        [0.6887254 ],
#        [0.29305655],
#        ...,
#        [0.8921794 ],
#        [0.88106817],
#        [1.0430331 ]], dtype=float32)

# %%
fig = plt.figure(figsize=(9,9))
ax = fig.gca(projection='3d')

# Make data
X = x_valid
Y = y_valid
X, Y = np.meshgrid(X, Y)
R = (X**2 + Y**2)
Z = np.sin(R)

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap="Blues",
                       linewidth=0, antialiased=False)
## Add points
ax.scatter(x_predicted, y_predicted, z_predicted , color="aqua", label = "Predicted")

ax.set_xlabel("x",size=13)
ax.set_ylabel("y",size=13)
ax.set_title("Predictions vs target function", size=13)
ax.legend(loc="upper right", fontsize=13)
ax.view_init(15, 20)
# Add a color bar which maps values to colors
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
N_train = 20000
N_valid = 2000

x_train = np.random.uniform(-3/2, 3/2, N_train)
y_train = np.random.uniform(-3/2, 3/2, N_train)

x_valid = np.random.uniform(-3/2, 3/2, N_valid)
y_valid = np.random.uniform(-3/2, 3/2, N_valid)
x_valid.sort()
y_valid.sort()

z_target = np.sin(x_valid**2 + y_valid**2)    #ideal (target) function

sigma = 0.25 # noise or standard deviation
z_train = np.random.normal(np.sin(x_train**2 + y_train**2), sigma) # actual measures from which we want to guess regression parameters
z_valid = np.random.normal(np.sin(x_valid**2 + y_valid**2), sigma)

# %%
#create new model
model_sin = Sequential()
model_sin.add(Dense(10, input_shape=(2,), activation='tanh'))
model_sin.add(Dense(20, activation='tanh'))
model_sin.add(Dense(20, activation='tanh'))
model_sin.add(Dense(1, activation='linear'))

#compile the model
model_sin.compile(optimizer='sgd', loss='mse', metrics=['mse'])

#return a summary for NN
model_sin.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_76 (Dense)             (None, 10)                30
# _________________________________________________________________
# dense_77 (Dense)             (None, 20)                220
# _________________________________________________________________
# dense_78 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_79 (Dense)             (None, 1)                 21
# =================================================================
# Total params: 691
# Trainable params: 691
# Non-trainable params: 0
# _________________________________________________________________

# %%
#prepare input
xx = np.array([x_train, y_train])
x1 = xx.transpose()

xx_valid = np.array([x_valid,y_valid])
xx_valid = xx_valid.transpose()

# %%
#fit the model
fit_sin = model_sin.fit(x=x1, y=z_train, batch_size=100, epochs=110,
                          shuffle=True, validation_data=(xx_valid, z_valid))
# Out:
# Epoch 1/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2276 - mse: 0.2276 - val_loss: 0.4426 - val_mse: 0.4426
# Epoch 2/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2147 - mse: 0.2147 - val_loss: 0.4367 - val_mse: 0.4367
# Epoch 3/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2144 - mse: 0.2144 - val_loss: 0.4314 - val_mse: 0.4314
# Epoch 4/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2139 - mse: 0.2139 - val_loss: 0.4280 - val_mse: 0.4280
# Epoch 5/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2133 - mse: 0.2133 - val_loss: 0.4262 - val_mse: 0.4262
# Epoch 6/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2129 - mse: 0.2129 - val_loss: 0.4223 - val_mse: 0.4223
# Epoch 7/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2127 - mse: 0.2127 - val_loss: 0.4337 - val_mse: 0.4337
# Epoch 8/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2123 - mse: 0.2123 - val_loss: 0.4290 - val_mse: 0.4290
# Epoch 9/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2120 - mse: 0.2120 - val_loss: 0.4305 - val_mse: 0.4305
# Epoch 10/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2117 - mse: 0.2117 - val_loss: 0.4292 - val_mse: 0.4292
# Epoch 11/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2113 - mse: 0.2113 - val_loss: 0.4230 - val_mse: 0.4230
# Epoch 12/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2110 - mse: 0.2110 - val_loss: 0.4322 - val_mse: 0.4322
# Epoch 13/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2104 - mse: 0.2104 - val_loss: 0.4206 - val_mse: 0.4206
# Epoch 14/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2099 - mse: 0.2099 - val_loss: 0.4414 - val_mse: 0.4414
# Epoch 15/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2095 - mse: 0.2095 - val_loss: 0.4294 - val_mse: 0.4294
# Epoch 16/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2089 - mse: 0.2089 - val_loss: 0.4194 - val_mse: 0.4194
# Epoch 17/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2083 - mse: 0.2083 - val_loss: 0.4213 - val_mse: 0.4213
# Epoch 18/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2076 - mse: 0.2076 - val_loss: 0.4288 - val_mse: 0.4288
# Epoch 19/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2066 - mse: 0.2066 - val_loss: 0.4102 - val_mse: 0.4102
# Epoch 20/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2057 - mse: 0.2057 - val_loss: 0.4148 - val_mse: 0.4148
# Epoch 21/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2045 - mse: 0.2045 - val_loss: 0.4096 - val_mse: 0.4096
# Epoch 22/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2031 - mse: 0.2031 - val_loss: 0.4123 - val_mse: 0.4123
# Epoch 23/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2013 - mse: 0.2013 - val_loss: 0.4032 - val_mse: 0.4032
# Epoch 24/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1993 - mse: 0.1993 - val_loss: 0.3941 - val_mse: 0.3941
# Epoch 25/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1970 - mse: 0.1970 - val_loss: 0.4043 - val_mse: 0.4043
# Epoch 26/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1944 - mse: 0.1944 - val_loss: 0.3893 - val_mse: 0.3893
# Epoch 27/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1914 - mse: 0.1914 - val_loss: 0.3731 - val_mse: 0.3731
# Epoch 28/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1882 - mse: 0.1882 - val_loss: 0.3767 - val_mse: 0.3767
# Epoch 29/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1844 - mse: 0.1844 - val_loss: 0.3759 - val_mse: 0.3759
# Epoch 30/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1805 - mse: 0.1805 - val_loss: 0.3708 - val_mse: 0.3708
# Epoch 31/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1763 - mse: 0.1763 - val_loss: 0.3552 - val_mse: 0.3552
# Epoch 32/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1724 - mse: 0.1724 - val_loss: 0.3606 - val_mse: 0.3606
# Epoch 33/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1684 - mse: 0.1684 - val_loss: 0.3442 - val_mse: 0.3442
# Epoch 34/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1645 - mse: 0.1645 - val_loss: 0.3444 - val_mse: 0.3444
# Epoch 35/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1610 - mse: 0.1610 - val_loss: 0.3317 - val_mse: 0.3317
# Epoch 36/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1580 - mse: 0.1580 - val_loss: 0.3264 - val_mse: 0.3264
# Epoch 37/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1553 - mse: 0.1553 - val_loss: 0.3244 - val_mse: 0.3244
# Epoch 38/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1530 - mse: 0.1530 - val_loss: 0.3145 - val_mse: 0.3145
# Epoch 39/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1510 - mse: 0.1510 - val_loss: 0.3097 - val_mse: 0.3097
# Epoch 40/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1491 - mse: 0.1491 - val_loss: 0.2993 - val_mse: 0.2993
# Epoch 41/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1478 - mse: 0.1478 - val_loss: 0.2962 - val_mse: 0.2962
# Epoch 42/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1464 - mse: 0.1464 - val_loss: 0.2972 - val_mse: 0.2972
# Epoch 43/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1452 - mse: 0.1452 - val_loss: 0.2831 - val_mse: 0.2831
# Epoch 44/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1441 - mse: 0.1441 - val_loss: 0.2835 - val_mse: 0.2835
# Epoch 45/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1431 - mse: 0.1431 - val_loss: 0.2832 - val_mse: 0.2832
# Epoch 46/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1422 - mse: 0.1422 - val_loss: 0.2755 - val_mse: 0.2755
# Epoch 47/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1414 - mse: 0.1414 - val_loss: 0.2672 - val_mse: 0.2672
# Epoch 48/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1406 - mse: 0.1406 - val_loss: 0.2675 - val_mse: 0.2675
# Epoch 49/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1396 - mse: 0.1396 - val_loss: 0.2605 - val_mse: 0.2605
# Epoch 50/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1387 - mse: 0.1387 - val_loss: 0.2603 - val_mse: 0.2603
# Epoch 51/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1380 - mse: 0.1380 - val_loss: 0.2530 - val_mse: 0.2530
# Epoch 52/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1370 - mse: 0.1370 - val_loss: 0.2469 - val_mse: 0.2469
# Epoch 53/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1361 - mse: 0.1361 - val_loss: 0.2508 - val_mse: 0.2508
# Epoch 54/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1354 - mse: 0.1354 - val_loss: 0.2424 - val_mse: 0.2424
# Epoch 55/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1346 - mse: 0.1346 - val_loss: 0.2449 - val_mse: 0.2449
# Epoch 56/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1335 - mse: 0.1335 - val_loss: 0.2394 - val_mse: 0.2394
# Epoch 57/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1327 - mse: 0.1327 - val_loss: 0.2385 - val_mse: 0.2385
# Epoch 58/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1319 - mse: 0.1319 - val_loss: 0.2371 - val_mse: 0.2371
# Epoch 59/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1309 - mse: 0.1309 - val_loss: 0.2297 - val_mse: 0.2297
# Epoch 60/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1299 - mse: 0.1299 - val_loss: 0.2264 - val_mse: 0.2264
# Epoch 61/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1292 - mse: 0.1292 - val_loss: 0.2263 - val_mse: 0.2263
# Epoch 62/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1282 - mse: 0.1282 - val_loss: 0.2236 - val_mse: 0.2236
# Epoch 63/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1271 - mse: 0.1271 - val_loss: 0.2204 - val_mse: 0.2204
# Epoch 64/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1262 - mse: 0.1262 - val_loss: 0.2157 - val_mse: 0.2157
# Epoch 65/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1252 - mse: 0.1252 - val_loss: 0.2145 - val_mse: 0.2145
# Epoch 66/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1239 - mse: 0.1239 - val_loss: 0.2102 - val_mse: 0.2102
# Epoch 67/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1231 - mse: 0.1231 - val_loss: 0.2109 - val_mse: 0.2109
# Epoch 68/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1219 - mse: 0.1219 - val_loss: 0.2054 - val_mse: 0.2054
# Epoch 69/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1207 - mse: 0.1207 - val_loss: 0.2022 - val_mse: 0.2022
# Epoch 70/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1197 - mse: 0.1197 - val_loss: 0.1984 - val_mse: 0.1984
# Epoch 71/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1184 - mse: 0.1184 - val_loss: 0.1959 - val_mse: 0.1959
# Epoch 72/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1170 - mse: 0.1170 - val_loss: 0.1938 - val_mse: 0.1938
# Epoch 73/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1159 - mse: 0.1159 - val_loss: 0.1926 - val_mse: 0.1926
# Epoch 74/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1144 - mse: 0.1144 - val_loss: 0.1893 - val_mse: 0.1893
# Epoch 75/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1132 - mse: 0.1132 - val_loss: 0.1862 - val_mse: 0.1862
# Epoch 76/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1118 - mse: 0.1118 - val_loss: 0.1840 - val_mse: 0.1840
# Epoch 77/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1105 - mse: 0.1105 - val_loss: 0.1784 - val_mse: 0.1784
# Epoch 78/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1089 - mse: 0.1089 - val_loss: 0.1761 - val_mse: 0.1761
# Epoch 79/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1075 - mse: 0.1075 - val_loss: 0.1737 - val_mse: 0.1737
# Epoch 80/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1062 - mse: 0.1062 - val_loss: 0.1704 - val_mse: 0.1704
# Epoch 81/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1046 - mse: 0.1046 - val_loss: 0.1646 - val_mse: 0.1646
# Epoch 82/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1031 - mse: 0.1031 - val_loss: 0.1634 - val_mse: 0.1634
# Epoch 83/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1017 - mse: 0.1017 - val_loss: 0.1604 - val_mse: 0.1604
# Epoch 84/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1000 - mse: 0.1000 - val_loss: 0.1561 - val_mse: 0.1561
# Epoch 85/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0987 - mse: 0.0987 - val_loss: 0.1484 - val_mse: 0.1484
# Epoch 86/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0971 - mse: 0.0971 - val_loss: 0.1489 - val_mse: 0.1489
# Epoch 87/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0955 - mse: 0.0955 - val_loss: 0.1437 - val_mse: 0.1437
# Epoch 88/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0939 - mse: 0.0939 - val_loss: 0.1418 - val_mse: 0.1418
# Epoch 89/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0925 - mse: 0.0925 - val_loss: 0.1371 - val_mse: 0.1371
# Epoch 90/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0910 - mse: 0.0910 - val_loss: 0.1325 - val_mse: 0.1325
# Epoch 91/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0896 - mse: 0.0896 - val_loss: 0.1329 - val_mse: 0.1329
# Epoch 92/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0880 - mse: 0.0880 - val_loss: 0.1254 - val_mse: 0.1254
# Epoch 93/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0865 - mse: 0.0865 - val_loss: 0.1192 - val_mse: 0.1192
# Epoch 94/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0852 - mse: 0.0852 - val_loss: 0.1229 - val_mse: 0.1229
# Epoch 95/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0838 - mse: 0.0838 - val_loss: 0.1136 - val_mse: 0.1136
# Epoch 96/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0826 - mse: 0.0826 - val_loss: 0.1092 - val_mse: 0.1092
# Epoch 97/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0812 - mse: 0.0812 - val_loss: 0.1092 - val_mse: 0.1092
# Epoch 98/110
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0800 - mse: 0.0800 - val_loss: 0.1017 - val_mse: 0.1017
# Epoch 99/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0789 - mse: 0.0789 - val_loss: 0.1002 - val_mse: 0.1002
# Epoch 100/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0778 - mse: 0.0778 - val_loss: 0.0952 - val_mse: 0.0952
# Epoch 101/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0769 - mse: 0.0769 - val_loss: 0.0947 - val_mse: 0.0947
# Epoch 102/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0760 - mse: 0.0760 - val_loss: 0.0921 - val_mse: 0.0921
# Epoch 103/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0748 - mse: 0.0748 - val_loss: 0.0908 - val_mse: 0.0908
# Epoch 104/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0742 - mse: 0.0742 - val_loss: 0.0871 - val_mse: 0.0871
# Epoch 105/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0733 - mse: 0.0733 - val_loss: 0.0849 - val_mse: 0.0849
# Epoch 106/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0728 - mse: 0.0728 - val_loss: 0.0840 - val_mse: 0.0840
# Epoch 107/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0722 - mse: 0.0722 - val_loss: 0.0826 - val_mse: 0.0826
# Epoch 108/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0713 - mse: 0.0713 - val_loss: 0.0800 - val_mse: 0.0800
# Epoch 109/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0711 - mse: 0.0711 - val_loss: 0.0776 - val_mse: 0.0776
# Epoch 110/110
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0703 - mse: 0.0703 - val_loss: 0.0779 - val_mse: 0.0779

# %%
plt.plot(fit_sin.history['loss'])
plt.plot(fit_sin.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
#abbassiamo leggermente sigma
sigma=0.1
##creiamo la funzione
def f(x, y):
    return np.sin(x**2+y**2)

# dataset
dat_train=np.zeros((30000,2))
dat_train[:,0]=np.random.uniform(-1.5, 1.5, 30000) 
dat_train[:,1]=np.random.uniform(-1.5, 1.5, 30000)

dat_valid=np.zeros((2000,2))
dat_valid[:,0]=np.random.uniform(-1.5, 1.5, 2000) 
dat_valid[:,1]=np.random.uniform(-1.5, 1.5, 2000)

fz_target=f(dat_valid[:,0],dat_valid[:,1]) 

# dataset + sigma
fz_train= np.random.normal(f(dat_train[:,0], dat_train[:,1]), sigma) 
fz_valid= np.random.normal(f(dat_valid[:,0], dat_valid[:,1]), sigma)

# %%
opt1='Adam'
opt2='sgd'

model = tf.keras.Sequential()
model.add(Dense(10, input_shape=(2,), activation="tanh"))
model.add(Dense(10, activation="tanh"))
model.add(Dense(10, activation="tanh"))
model.add(Dense(10, activation="tanh"))
model.add(Dense(1,activation="linear"))
model.compile(optimizer=opt1, loss="mse", metrics=['mse'])
history= model.fit(dat_train, fz_train, batch_size=32, epochs=100, validation_data=(dat_valid, fz_valid)) #callbacks=[ plot_estimate, earlystop],
# Out:
# Epoch 1/100
# 938/938 [==============================] - 1s 2ms/step - loss: 0.1665 - mse: 0.1665 - val_loss: 0.1510 - val_mse: 0.1510
# Epoch 2/100
# 938/938 [==============================] - 1s 1ms/step - loss: 0.1421 - mse: 0.1421 - val_loss: 0.0998 - val_mse: 0.0998
# Epoch 3/100
# 938/938 [==============================] - 1s 1ms/step - loss: 0.0704 - mse: 0.0704 - val_loss: 0.0429 - val_mse: 0.0429
# Epoch 4/100
# 833/938 [=========================>....] - ETA: 0s - loss: 0.0383 - mse: 0.0383
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-113-e00750f315f1> in <module>
#       9 model.add(Dense(1,activation="linear"))
#      10 model.compile(optimizer=opt1, loss="mse", metrics=['mse'])
# ---> 11 history= model.fit(dat_train, fz_train, batch_size=32, epochs=100, validation_data=(dat_valid, fz_valid)) #callbacks=[ plot_estimate, earlystop],
#      12
#
# /anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# /anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# /anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# /anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# /anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# /anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# /anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# /anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
dat_valid
# Out:
# array([[-0.57922199,  0.38605482],
#        [ 0.89964282, -0.00314031],
#        [-0.1511412 , -0.44314009],
#        ...,
#        [ 1.09762546, -0.61325556],
#        [-0.58153384, -0.59108901],
#        [-1.10261258, -0.02527123]])

# %%
 fz_valid
# Out:
# array([0.46519632, 0.59686141, 0.16313885, ..., 0.953667  , 0.62332577,
#        0.67570232])
